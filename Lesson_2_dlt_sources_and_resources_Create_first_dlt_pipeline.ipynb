# %% [markdown]
# # **dlt sources and resources**: Create first dlt pipeline.

# %% [markdown]
# ![0uv934osx6pb1.png](data:image/png;base64,...)

# %% [markdown]
# ## Recap of [Lesson 1](https://colab.research.google.com/drive/1QwlDWxX5hvwbHMkCgiF0UCzGFRMRoSPY?usp=sharing) 👩‍💻🚀
# 1. Created a pipeline, loaded toy data into DuckDB, and viewed load info.
# 2. Used `dlt.pipeline` and `pipeline.run` methods.
# 3. Used DuckDB, `sql_client` and dlt `dataset` to view tables and query data.
#
# Now we move to the next lesson to learn more details about dlt! 🚀

# %% [markdown]
# **Here, you will learn how to:**
# - Run a simple pipeline with different types of data, such as dataframes, databases and RestAPI.
# - Use `dlt.resource`, `dlt.source` and `dlt.transformer`.
# - Build your first dlt pipeline for RestAPI.

# %% [markdown]
# ## **Install dlt**

# %%
# %%capture
# !pip install dlt
# Use duckdb connection, sql_client or pipeline.dataset()
# !pip install "dlt[duckdb]"

# %% [markdown]
# ---
# ## **`dlt` resources**

# %% [markdown]
# ---
# ### List of dicts
#
#
# In the previous lesson, we simply used a list of dictionaries that essentially represents the `pokemon` table.

# %%
import dlt

# Sample data containing pokemon details
data = [
    {"id": "1", "name": "bulbasaur", "size": {"weight": 6.9, "height": 0.7}},
    {"id": "4", "name": "charmander", "size": {"weight": 8.5, "height": 0.6}},
    {"id": "25", "name": "pikachu", "size": {"weight": 6, "height": 0.4}},
]


# Set pipeline name, destination, and dataset name
pipeline = dlt.pipeline(
    pipeline_name="quick_start",
    destination="duckdb",
    dataset_name="mydata",
)

# Run the pipeline with data and table name
load_info = pipeline.run(data, table_name="pokemon")

print(load_info)
# Out:
# Pipeline quick_start load step completed in 0.25 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset mydata
# The duckdb destination used duckdb:////content/quick_start.duckdb location to store data
# Load package 1735261690.4072917 is LOADED and contains no failed jobs

# %% [markdown]
# A better way is to wrap it in the `@dlt.resource` decorator which denotes a logical grouping of data within a data source, typically holding data of similar structure and origin:

# %%
import dlt

# Create a dlt resource from the data
@dlt.resource(table_name='pokemon_new') # <--- we set new table name
def my_dict_list():
    yield data

# %% [markdown]
# Commonly used arguments:
#
# * **`name`**: The resource name and the name of the table generated by this resource. Defaults to the decorated function name.
# * **`table_name`**: the name of the table, if different from the resource name.
# * **`write_disposition`**: controls how to write data to a table. Defaults to "append".

# %% [markdown]
# > **Why is it a better way?** This allows you to use `dlt` functionalities to the fullest that follow Data Engineering best practices, including incremental loading and data contracts.

# %% [markdown]
# Try running the pipeline with the `my_dict_list` resource:

# %%
# Run the pipeline and print load info
load_info = pipeline.run(my_dict_list)
print(load_info)
# Out:
# Pipeline quick_start load step completed in 0.15 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset mydata
# The duckdb destination used duckdb:////content/quick_start.duckdb location to store data
# Load package 1735261691.171659 is LOADED and contains no failed jobs

# %% [markdown]
# Check what was loaded to the `pokemon_new` table:

# %%
pipeline.dataset()

# %%
pipeline.dataset(dataset_type="default")

# %%
pipeline.dataset(dataset_type="default").pokemon_new.df()
# Out:
#    id        name  size__weight  size__height        _dlt_load_id  \
# 0   1   bulbasaur           6.9           0.7   1735255398.734018
# 1   4  charmander           8.5           0.6   1735255398.734018
# 2  25     pikachu           6.0           0.4   1735255398.734018
# 3   1   bulbasaur           6.9           0.7  1735261509.5229492
# 4   4  charmander           8.5           0.6  1735261509.5229492
# 5  25     pikachu           6.0           0.4  1735261509.5229492
# 6   1   bulbasaur           6.9           0.7   1735261691.171659
# 7   4  charmander           8.5           0.6   1735261691.171659
# 8  25     pikachu           6.0           0.4   1735261691.171659
#
#           _dlt_id
# 0  S5wdTirddSIofg
# 1  WAkANZqjPdXbsA
# 2  D71fij/XSI/nBg
# 3  4K7rMsXgqTr9Dg
# 4  u8omc7wDfHqJpA
# 5  GpWMifcLOLHGyA
# 6  PmaBmP2YBvfetg
# 7  65JgcxlrCdio+w
# 8  zQ0ms7X2AAo26w

# %% [markdown]
# Instead of a dict list, the data could also be a/an:
# - dataframe
# - database query response
# - API request response
# - Anything you can transform into JSON/dict format

# %% [markdown]
# ---
# ### Dataframes
# For creating a pipeline using dataframes, you would do:

# %%
import pandas as pd

# Define a resource to load data from a CSV
@dlt.resource(table_name='df_data')
def my_df():
  sample_df = pd.read_csv("https://people.sc.fsu.edu/~jburkardt/data/csv/hw_200.csv")
  yield sample_df


# Run the pipeline with the defined resource
load_info = pipeline.run(my_df)
print(load_info)

# Query the loaded data from 'df_data'
pipeline.dataset(dataset_type="default").df_data.df()
# Out:
# Pipeline quick_start load step completed in 0.13 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset mydata
# The duckdb destination used duckdb:////content/quick_start.duckdb location to store data
# Load package 1735261692.037634 is LOADED and contains no failed jobs
#      index  height_inchesx  _weight_poundsx
# 0        1           65.78           112.99
# 1        2           71.52           136.49
# 2        3           69.40           153.03
# 3        4           68.22           142.34
# 4        5           67.79           144.30
# ..     ...             ...              ...
# 995    196           65.80           120.84
# 996    197           66.11           115.78
# 997    198           68.24           128.30
# 998    199           68.02           127.47
# 999    200           71.39           127.88
#
# [1000 rows x 3 columns]

# %% [markdown]
# ---
# ### Database
#
# For creating a pipeline from an SQL database query you would do:
#
# 1. Install the PyMySQL package:

# %%
# %%capture
# !pip install pymysql

# %% [markdown]
# 2. Create and run a pipeline to fetch data from an SQL resource and query the loaded data as follows:

# %%
import dlt
from sqlalchemy import create_engine

# Define a resource to fetch genome data from the database
@dlt.resource(table_name='genome_data')
def get_genome_data():
  engine = create_engine("mysql+pymysql://rfamro@mysql-rfam-public.ebi.ac.uk:4497/Rfam")
  with engine.connect() as conn:
      query = "SELECT * FROM genome LIMIT 1000"
      rows = conn.execution_options(yield_per=100).exec_driver_sql(query)
      yield from map(lambda row: dict(row._mapping), rows)

# Run the pipeline with the genome data resource
load_info = pipeline.run(get_genome_data)
print(load_info)

# Query the loaded data from 'genome_data'
pipeline.dataset(dataset_type="default").genome_data.df()
# Out:
# Pipeline quick_start load step completed in 0.91 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset mydata
# The duckdb destination used duckdb:////content/quick_start.duckdb location to store data
# Load package 1735261699.0479736 is LOADED and contains no failed jobs
#              upid                                        description  \
# 0     RG000000001                        Potato spindle tuber viroid
# 1     RG000000002                             Columnea latent viroid
# 2     RG000000003                       Tomato apical stunt viroid-S
# 3     RG000000004                         Tomato apical stunt viroid
# 4     RG000000005                             Cucumber yellows virus
# ...           ...                                                ...
# 4995  UP000001264                                               None
# 4996  UP000001265                         Enterococcus phage phiFL4A
# 4997  UP000001266                           Staphylococcus phage SA1
# 4998  UP000001270                        Mycobacterium phage AnnaL29
# 4999  UP000001274  ASM28353v1 assembly for Pseudogulbenkiania sp....
#
#       total_length  ncbi_id               scientific_name   kingdom  \
# 0             4591    12892   Potato spindle tuber viroid   viroids
# 1              370    12901        Columnea latent viroid   viroids
# 2              360    53194  Tomato apical stunt viroid-S   viroids
# 3              360    12885    Tomato apical stunt viroid   viroids
# 4             7899    32618        Cucumber yellows virus   viruses
# ...            ...      ...                           ...       ...
# 4995         40275   673838    Enterococcus phage phiFL3B   viruses
# 4996         37856   673839    Enterococcus phage phiFL4A   viruses
# 4997        147303   694060      Staphylococcus phage SA1   viruses
# 4998         53253  1076630   Mycobacterium phage AnnaL29   viruses
# 4999       4332995   748280   Pseudogulbenkiania sp. NH8B  bacteria
#
#       num_rfam_regions  num_families  is_reference  is_representative  ...  \
# 0                    0             0             1                  0  ...
# 1                    0             0             1                  0  ...
# 2                    0             0             1                  0  ...
# 3                    0             0             1                  0  ...
# 4                    0             0             1                  0  ...
# ...                ...           ...           ...                ...  ...
# 4995                 0             0             0                  1  ...
# 4996                 2             2             0                  1  ...
# 4997                 0             0             0                  1  ...
# 4998                 0             0             0                  1  ...
# 4999               143            33             0                  1  ...
#
#          assembly_acc assembly_version   assembly_level ungapped_length  \
# 0                None              NaN             None             NaN
# 1                None              NaN             None             NaN
# 2                None              NaN             None             NaN
# 3                None              NaN             None             NaN
# 4                None              NaN             None             NaN
# ...               ...              ...              ...             ...
# 4995  GCA_002630665.1              1.0  complete-genome             NaN
# 4996                               0.0                              0.0
# 4997                               0.0                              0.0
# 4998                               0.0                              0.0
# 4999  GCA_000283535.1              1.0  complete-genome       4332995.0
#
#      assembly_name   study_ref circular  wgs_acc wgs_version common_name
# 0             None        None      NaN     None         NaN        None
# 1             None        None      NaN     None         NaN        None
# 2             None        None      NaN     None         NaN        None
# 3             None        None      NaN     None         NaN        None
# 4             None        None      NaN     None         NaN        None
# ...            ...         ...      ...      ...         ...         ...
# 4995   ASM263066v1        None      NaN     None         NaN        None
# 4996                                0.0                  0.0
# 4997                                0.0                  0.0
# 4998                                0.0                  0.0
# 4999    ASM28353v1  PRJDA68325      NaN     None         NaN        None
#
# [5000 rows x 24 columns]

# %% [markdown]
# ---
# ### REST API
#
# For REST API endpoints, create a pipeline as follows:

# %%
from dlt.sources.helpers import requests


# Define a resource to fetch pokemons from PokeAPI
@dlt.resource(table_name='pokemon_api')
def get_pokemon():
    url = "https://pokeapi.co/api/v2/pokemon"
    response = requests.get(url)
    yield response.json()["results"]


# Run the pipeline using the defined resource
load_info = pipeline.run(get_pokemon)
print(load_info)

# Query the loaded data from 'pokemon_api' table
pipeline.dataset(dataset_type="default").pokemon_api.df()
# Out:
# Pipeline quick_start load step completed in 0.15 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset mydata
# The duckdb destination used duckdb:////content/quick_start.duckdb location to store data
# Load package 1735261704.162351 is LOADED and contains no failed jobs
#           name                                    url       _dlt_load_id  \
# 0    bulbasaur   https://pokeapi.co/api/v2/pokemon/1/  1735255418.783993
# 1      ivysaur   https://pokeapi.co/api/v2/pokemon/2/  1735255418.783993
# 2     venusaur   https://pokeapi.co/api/v2/pokemon/3/  1735255418.783993
# 3   charmander   https://pokeapi.co/api/v2/pokemon/4/  1735255418.783993
# 4   charmeleon   https://pokeapi.co/api/v2/pokemon/5/  1735255418.783993
# ..         ...                                    ...                ...
# 95      pidgey  https://pokeapi.co/api/v2/pokemon/16/  1735261704.162351
# 96   pidgeotto  https://pokeapi.co/api/v2/pokemon/17/  1735261704.162351
# 97     pidgeot  https://pokeapi.co/api/v2/pokemon/18/  1735261704.162351
# 98     rattata  https://pokeapi.co/api/v2/pokemon/19/  1735261704.162351
# 99    raticate  https://pokeapi.co/api/v2/pokemon/20/  1735261704.162351
#
#            _dlt_id
# 0   zYudota9p4AVBQ
# 1   t5qwiPuR6Oy0bg
# 2   1reIwMWYZ7FKqQ
# 3   BB2tVv6pnP9+/w
# 4   O7uZvzpEL/Eu0w
# ..             ...
# 95  sWDWpSwi3MXGEg
# 96  /69dLPsYXj/wnA
# 97  FIeMMU2W4u65OA
# 98  rAEQaZyrM1OpDQ
# 99  URQDf/JD8dPeAg
#
# [100 rows x 4 columns]

# %% [markdown]
# Try loading everything above, in a single pipeline:

# %%
load_info = pipeline.run([my_df, get_genome_data, get_pokemon])
print(load_info)
# Out:
# Pipeline quick_start load step completed in 0.81 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset mydata
# The duckdb destination used duckdb:////content/quick_start.duckdb location to store data
# Load package 1735261705.0354288 is LOADED and contains no failed jobs

# %% [markdown]
# Check which new tables were created:

# %%
# List all table names from the database
with pipeline.sql_client() as client:
    with client.execute_query("SELECT table_name FROM information_schema.tables") as table:
        print(table.df())
# Out:
#             table_name
# 0              df_data
# 1          genome_data
# 2              pokemon
# 3          pokemon_api
# 4          pokemon_new
# 5           _dlt_loads
# 6  _dlt_pipeline_state
# 7         _dlt_version

# %% [markdown]
# ---
# ## **`dlt` sources**

# %% [markdown]
# Now that there are multiple `dlt` resources, each corresponding to a separate table, we can group them into a `dlt` source.

# %% [markdown]
# ![Screenshot 2024-12-05 at 16.59.40.png](data:image/png;base64,...)

# %% [markdown]
# A source is a logical grouping of resources, e.g., endpoints of a single API. The most common approach is to define it in a separate Python module.
#
# * A source is a function decorated with `@dlt.source` that returns one or more resources.
# * A source can optionally define a schema with tables, columns, performance hints, and more.
# * The source Python module typically contains optional customizations and data transformations.
# * The source Python module typically contains the authentication and pagination code for a particular API.
#
# Read more about [sources](https://dlthub.com/docs/general-usage/source) and [resources](https://dlthub.com/docs/general-usage/resource) here.

# %% [markdown]
# You declare a source by decorating a function that returns or yields one or more resources with `@dlt.source`.
#
# Here's how it's done:

# %%
@dlt.source
def all_data():
  return my_df, get_genome_data, get_pokemon

# %% [markdown]
# Only using the source above, load everything into a separate database using a new pipeline:

# %%
# Create a pipeline
pipeline = dlt.pipeline(
    pipeline_name="resource_source_new",
    destination="duckdb",
    dataset_name="all_data"
)

# Run the pipeline
load_info = pipeline.run(all_data())

# Print load info
print(load_info)
# Out:
# Pipeline resource_source_new load step completed in 0.97 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset all_data
# The duckdb destination used duckdb:////content/resource_source_new.duckdb location to store data
# Load package 1735261710.307749 is LOADED and contains no failed jobs

# %% [markdown]
# > **Why does this matter?**:
# - It is more efficient than running your resources separately.
# - It organizes both your schema and your code. 🙂
# - It enables the option for parallelization.

# %% [markdown]
# ---
# ## **`dlt` transformers**

# %% [markdown]
# We now know that `dlt` resources can be grouped into a `dlt` source, represented as:
#
#
# ```
#                   Source
#                /          \
#           Resource 1  ...  Resource N
#
# ```
#
# However, imagine a scenario where you need an additional step in between:
#
# ```
#                   Source
#                  /     \
#              step        \
#              /             \
#         Resource 1  ...  Resource N
#
# ```
#
# This step could arise, for example, in a situation where:
#
# - Resource 1 returns a list of pokemons IDs, and you need to use each of those IDs to retrieve detailed information about the pokemons from a separate API endpoint.
#
# In such cases, you would use `dlt` transformers — special `dlt` resources that can be fed data from another resource:
#
# ```
#                   Source
#                  /     \
#           Transformer    \
#              /             \
#         Resource 1  ...  Resource N
#
# ```

# %% [markdown]
# Let’s assume Resource 1 is:

# %%
@dlt.resource(table_name='pokemon')
def my_dict_list():
    yield data

# %% [markdown]
# We need to get detailed information about pokemons from [PokeAPI](https://pokeapi.co/) `"https://pokeapi.co/api/v2/pokemon/{id}"` based on their IDs. We would do:

# %%
# Define a transformer to enrich pokemon data with additional details
@dlt.transformer(data_from=my_dict_list, table_name='detailed_info')
def poke_details(items): # <--- `items` is a variable and contains data from `my_dict_list` resource
    for item in items:

      print(f"Item: {item}\n") # <-- print what data we get from `my_dict_list` source

      id = item["id"]
      url = f"https://pokeapi.co/api/v2/pokemon/{id}"
      response = requests.get(url)
      details = response.json()

      print(f"Details: {details}\n") # <--- print what data we get from API

      yield details

# %% [markdown]
# Run the pipeline:

# %%
import requests
load_info = pipeline.run(poke_details())
print(load_info)
# Out:
# Item: {'id': '1', 'name': 'bulbasaur', 'size': {'weight': 6.9, 'height': 0.7}}
#
# Details: {'abilities': [{'ability': {'name': 'overgrow', 'url': 'https://pokeapi.co/api/v2/ability/65/'}, 'is_hidden': False, 'slot': 1}, {'ability': {'name': 'chlorophyll', 'url': 'https://pokeapi.co/api/v2/ability/34/'}, 'is_hidden': True, 'slot': 3}], 'base_experience': 64, 'cries': {'latest': 'https://raw.githubusercontent.com/PokeAPI/cries/main/cries/pokemon/latest/1.ogg', 'legacy': 'https://raw.githubusercontent.com/PokeAPI/cries/main/cries/pokemon/legacy/1.ogg'}, 'forms': [{'name': 'bulbasaur', 'url': 'https://pokeapi.co/api/v2/pokemon-form/1/'}], 'game_indices': [{'game_index': 153, 'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}}, {'game_index': 153, 'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}}, {'game_index': 153, 'version': {'name': 'yellow', 'url': 'https://pokeapi.co/api/v2/version/3/'}}, {'game_index': 1, 'version': {'name': 'gold', 'url': 'https://pokeapi.co/api/v2/version/4/'}}, {'game_index': 1, 'version': {'name': 'silver', 'url': 'https://pokeapi.co/api/v2/version/5/'}}, {'game_index': 1, 'version': {'name': 'crystal', 'url': 'https://pokeapi.co/api/v2/version/6/'}}, {'game_index': 1, 'version': {'name': 'ruby', 'url': 'https://pokeapi.co/api/v2/version/7/'}}, {'game_index': 1, 'version': {'name': 'sapphire', 'url': 'https://pokeapi.co/api/v2/version/8/'}}, {'game_index': 1, 'version': {'name': 'emerald', 'url': 'https://pokeapi.co/api/v2/version/9/'}}, {'game_index': 1, 'version': {'name': 'firered', 'url': 'https://pokeapi.co/api/v2/version/10/'}}, {'game_index': 1, 'version': {'name': 'leafgreen', 'url': 'https://pokeapi.co/api/v2/version/11/'}}, {'game_index': 1, 'version': {'name': 'diamond', 'url': 'https://pokeapi.co/api/v2/version/12/'}}, {'game_index': 1, 'version': {'name': 'pearl', 'url': 'https://pokeapi.co/api/v2/version/13/'}}, {'game_index': 1, 'version': {'name': 'platinum', 'url': 'https://pokeapi.co/api/v2/version/14/'}}, {'game_index': 1, 'version': {'name': 'heartgold', 'url': 'https://pokeapi.co/api/v2/version/15/'}}, {'game_index': 1, 'version': {'name': 'soulsilver', 'url': 'https://pokeapi.co/api/v2/version/16/'}}, {'game_index': 1, 'version': {'name': 'black', 'url': 'https://pokeapi.co/api/v2/version/17/'}}, {'game_index': 1, 'version': {'name': 'white', 'url': 'https://pokeapi.co/api/v2/version/18/'}}, {'game_index': 1, 'version': {'name': 'black-2', 'url': 'https://pokeapi.co/api/v2/version/21/'}}, {'game_index': 1, 'version': {'name': 'white-2', 'url': 'https://pokeapi.co/api/v2/version/22/'}}], 'height': 7, 'held_items': [], 'id': 1, 'is_default': True, 'location_area_encounters': 'https://pokeapi.co/api/v2/pokemon/1/encounters', 'moves': [{'move': {'name': 'razor-wind', 'url': 'https://pokeapi.co/api/v2/move/13/'}, 'version_group_details': [{'level_learned_at': 0, 'move_learn_method': {'name': 'egg', 'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'}, 'version_group': {'name': 'gold-silver', 'url': 'https://pokeapi.co/api/v2/version-group/3/'}}, {'level_learned_at': 0, 'move_learn_method': {'name': 'egg', 'url': 'https://pokeapi.co/api/v2/move-learn-method/2/'}, 'version_group': {'name': 'crystal', 'url': 'https://pokeapi.co/api/v2/version-group/4/'}}]}, {'move': {'name': 'swords-dance', 'url': 'https://pokeapi.co/api/v2/move/14/'}, 'version_group_details': [{'level_learned_at': 0, 'move_learn_method': {'name': 'machine', 'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'}, 'version_group': {'name': 'red-blue', 'url': 'https://pokeapi.co/api/v2/version-group/1/'}}, {'level_learned_at': 0, 'move_learn_method': {'name': 'machine', 'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'}, 'version_group': {'name': 'yellow', 'url': 'https://pokeapi.co/api/v2/version-group/2/'}}, {'level_learned_at': 0, 'move_learn_method': {'name': 'tutor', 'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'}, 'version_group': {'name': 'emerald', 'url': 'https://pokeapi.co/api/v2/version-group/6/'}}, {'level_learned_at': 0, 'mo ...
#
# Item: {'id': '4', 'name': 'charmander', 'size': {'weight': 8.5, 'height': 0.6}}
#
# Details: {'abilities': [{'ability': {'name': 'blaze', 'url': 'https://pokeapi.co/api/v2/ability/66/'}, 'is_hidden': False, 'slot': 1}, {'ability': {'name': 'solar-power', 'url': 'https://pokeapi.co/api/v2/ability/94/'}, 'is_hidden': True, 'slot': 3}], 'base_experience': 62, 'cries': {'latest': 'https://raw.githubusercontent.com/PokeAPI/cries/main/cries/pokemon/latest/4.ogg', 'legacy': 'https://raw.githubusercontent.com/PokeAPI/cries/main/cries/pokemon/legacy/4.ogg'}, 'forms': [{'name': 'charmander', 'url': 'https://pokeapi.co/api/v2/pokemon-form/4/'}], 'game_indices': [{'game_index': 176, 'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}}, {'game_index': 176, 'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}}, {'game_index': 176, 'version': {'name': 'yellow', 'url': 'https://pokeapi.co/api/v2/version/3/'}}, {'game_index': 4, 'version': {'name': 'gold', 'url': 'https://pokeapi.co/api/v2/version/4/'}}, {'game_index': 4, 'version': {'name': 'silver', 'url': 'https://pokeapi.co/api/v2/version/5/'}}, {'game_index': 4, 'version': {'name': 'crystal', 'url': 'https://pokeapi.co/api/v2/version/6/'}}, {'game_index': 4, 'version': {'name': 'ruby', 'url': 'https://pokeapi.co/api/v2/version/7/'}}, {'game_index': 4, 'version': {'name': 'sapphire', 'url': 'https://pokeapi.co/api/v2/version/8/'}}, {'game_index': 4, 'version': {'name': 'emerald', 'url': 'https://pokeapi.co/api/v2/version/9/'}}, {'game_index': 4, 'version': {'name': 'firered', 'url': 'https://pokeapi.co/api/v2/version/10/'}}, {'game_index': 4, 'version': {'name': 'leafgreen', 'url': 'https://pokeapi.co/api/v2/version/11/'}}, {'game_index': 4, 'version': {'name': 'diamond', 'url': 'https://pokeapi.co/api/v2/version/12/'}}, {'game_index': 4, 'version': {'name': 'pearl', 'url': 'https://pokeapi.co/api/v2/version/13/'}}, {'game_index': 4, 'version': {'name': 'platinum', 'url': 'https://pokeapi.co/api/v2/version/14/'}}, {'game_index': 4, 'version': {'name': 'heartgold', 'url': 'https://pokeapi.co/api/v2/version/15/'}}, {'game_index': 4, 'version': {'name': 'soulsilver', 'url': 'https://pokeapi.co/api/v2/version/16/'}}, {'game_index': 4, 'version': {'name': 'black', 'url': 'https://pokeapi.co/api/v2/version/17/'}}, {'game_index': 4, 'version': {'name': 'white', 'url': 'https://pokeapi.co/api/v2/version/18/'}}, {'game_index': 4, 'version': {'name': 'black-2', 'url': 'https://pokeapi.co/api/v2/version/21/'}}, {'game_index': 4, 'version': {'name': 'white-2', 'url': 'https://pokeapi.co/api/v2/version/22/'}}], 'height': 6, 'held_items': [], 'id': 4, 'is_default': True, 'location_area_encounters': 'https://pokeapi.co/api/v2/pokemon/4/encounters', 'moves': [{'move': {'name': 'mega-punch', 'url': 'https://pokeapi.co/api/v2/move/5/'}, 'version_group_details': [{'level_learned_at': 0, 'move_learn_method': {'name': 'machine', 'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'}, 'version_group': {'name': 'red-blue', 'url': 'https://pokeapi.co/api/v2/version-group/1/'}}, {'level_learned_at': 0, 'move_learn_method': {'name': 'machine', 'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'}, 'version_group': {'name': 'yellow', 'url': 'https://pokeapi.co/api/v2/version-group/2/'}}, {'level_learned_at': 0, 'move_learn_method': {'name': 'tutor', 'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'}, 'version_group': {'name': 'emerald', 'url': 'https://pokeapi.co/api/v2/version-group/6/'}}, {'level_learned_at': 0, 'move_learn_method': {'name': 'tutor', 'url': 'https://pokeapi.co/api/v2/move-learn-method/3/'}, 'version_group': {'name': 'firered-leafgreen', 'url': 'https://pokeapi.co/api/v2/version-group/7/'}}, {'level_learned_at': 0, 'move_learn_method': {'name': 'machine', 'url': 'https://pokeapi.co/api/v2/move-learn-method/4/'}, 'version_group': {'name': 'sword-shield', 'url': 'https://pokeapi.co/api/v2/version-group/20/'}}]}, {'move': {'name': 'fire-punch', 'url': 'https://pokeapi.co/api/v2/move/7/'}, 'version_group_details': [{'level_learned ...
#
# Item: {'id': '25', 'name': 'pikachu', 'size': {'weight': 6, 'height': 0.4}}
#
# Details: {'abilities': [{'ability': {'name': 'static', 'url': 'https://pokeapi.co/api/v2/ability/9/'}, 'is_hidden': False, 'slot': 1}, {'ability': {'name': 'lightning-rod', 'url': 'https://pokeapi.co/api/v2/ability/31/'}, 'is_hidden': True, 'slot': 3}], 'base_experience': 112, 'cries': {'latest': 'https://raw.githubusercontent.com/PokeAPI/cries/main/cries/pokemon/latest/25.ogg', 'legacy': 'https://raw.githubusercontent.com/PokeAPI/cries/main/cries/pokemon/legacy/25.ogg'}, 'forms': [{'name': 'pikachu', 'url': 'https://pokeapi.co/api/v2/pokemon-form/25/'}], 'game_indices': [{'game_index': 84, 'version': {'name': 'red', 'url': 'https://pokeapi.co/api/v2/version/1/'}}, {'game_index': 84, 'version': {'name': 'blue', 'url': 'https://pokeapi.co/api/v2/version/2/'}}, {'game_index': 84, 'version': {'name': 'yellow', 'url': 'https://pokeapi.co/api/v2/version/3/'}}, {'game_index': 25, 'version': {'name': 'gold', 'url': 'https://pokeapi.co/api/v2/version/4/'}}, {'game_index': 25, 'version': {'name': 'silver', 'url': 'https://pokeapi.co/api/v2/version/5/'}}, {'game_index': 25, 'version': {'name': 'crystal', 'url': 'https://pokeapi.co/api/v2/version/6/'}}, {'game_index': 25, 'version': {'name': 'ruby', 'url': 'https://pokeapi.co/api/v2/version/7/'}}, {'game_index': 25, 'version': {'name': 'sapphire', 'url': 'https://pokeapi.co/api/v2/version/8/'}}, {'game_index': 25, 'version': {'name': 'emerald', 'url': 'https://pokeapi.co/api/v2/version/9/'}}, {'game_index': 25, 'version': {'name': 'firered', 'url': 'https://pokeapi.co/api/v2/version/10/'}}, {'game_index': 25, 'version': {'name': 'leafgreen', 'url': 'https://pokeapi.co/api/v2/version/11/'}}, {'game_index': 25, 'version': {'name': 'diamond', 'url': 'https://pokeapi.co/api/v2/version/12/'}}, {'game_index': 25, 'version': {'name': 'pearl', 'url': 'https://pokeapi.co/api/v2/version/13/'}}, {'game_index': 25, 'version': {'name': 'platinum', 'url': 'https://pokeapi.co/api/v2/version/14/'}}, {'game_index': 25, 'version': {'name': 'heartgold', 'url': 'https://pokeapi.co/api/v2/version/15/'}}, {'game_index': 25, 'version': {'name': 'soulsilver', 'url': 'https://pokeapi.co/api/v2/version/16/'}}, {'game_index': 25, 'version': {'name': 'black', 'url': 'https://pokeapi.co/api/v2/version/17/'}}, {'game_index': 25, 'version': {'name': 'white', 'url': 'https://pokeapi.co/api/v2/version/18/'}}, {'game_index': 25, 'version': {'name': 'black-2', 'url': 'https://pokeapi.co/api/v2/version/21/'}}, {'game_index': 25, 'version': {'name': 'white-2', 'url': 'https://pokeapi.co/api/v2/version/22/'}}], 'height': 4, 'held_items': [{'item': {'name': 'oran-berry', 'url': 'https://pokeapi.co/api/v2/item/132/'}, 'version_details': [{'rarity': 50, 'version': {'name': 'ruby', 'url': 'https://pokeapi.co/api/v2/version/7/'}}, {'rarity': 50, 'version': {'name': 'sapphire', 'url': 'https://pokeapi.co/api/v2/version/8/'}}, {'rarity': 50, 'version': {'name': 'emerald', 'url': 'https://pokeapi.co/api/v2/version/9/'}}, {'rarity': 50, 'version': {'name': 'diamond', 'url': 'https://pokeapi.co/api/v2/version/12/'}}, {'rarity': 50, 'version': {'name': 'pearl', 'url': 'https://pokeapi.co/api/v2/version/13/'}}, {'rarity': 50, 'version': {'name': 'platinum', 'url': 'https://pokeapi.co/api/v2/version/14/'}}, {'rarity': 50, 'version': {'name': 'heartgold', 'url': 'https://pokeapi.co/api/v2/version/15/'}}, {'rarity': 50, 'version': {'name': 'soulsilver', 'url': 'https://pokeapi.co/api/v2/version/16/'}}, {'rarity': 50, 'version': {'name': 'black', 'url': 'https://pokeapi.co/api/v2/version/17/'}}, {'rarity': 50, 'version': {'name': 'white', 'url': 'https://pokeapi.co/api/v2/version/18/'}}]}, {'item': {'name': 'light-ball', 'url': 'https://pokeapi.co/api/v2/item/213/'}, 'version_details': [{'rarity': 5, 'version': {'name': 'ruby', 'url': 'https://pokeapi.co/api/v2/version/7/'}}, {'rarity': 5, 'version': {'name': 'sapphire', 'url': 'https://pokeapi.co/api/v2/version/8/'}}, {'rarity': 5, 'version': {'name': 'emerald', 'url': 'https://pokeapi.co/ ...
#
# Pipeline resource_source_new load step completed in 1.35 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset all_data
# The duckdb destination used duckdb:////content/resource_source_new.duckdb location to store data
# Load package 1735261717.728833 is LOADED and contains no failed jobs

# %%
# Query the 'detailed_info' table and convert the result to a DataFrame
pipeline.dataset(dataset_type="default").detailed_info.df()
# Out:
#     base_experience                                      cries__latest  \
# 0                64  https://raw.githubusercontent.com/PokeAPI/crie...
# 1                62  https://raw.githubusercontent.com/PokeAPI/crie...
# 2               112  https://raw.githubusercontent.com/PokeAPI/crie...
# 3                64  https://raw.githubusercontent.com/PokeAPI/crie...
# 4                62  https://raw.githubusercontent.com/PokeAPI/crie...
# 5               112  https://raw.githubusercontent.com/PokeAPI/crie...
# 6                64  https://raw.githubusercontent.com/PokeAPI/crie...
# 7                62  https://raw.githubusercontent.com/PokeAPI/crie...
# 8               112  https://raw.githubusercontent.com/PokeAPI/crie...
# 9                64  https://raw.githubusercontent.com/PokeAPI/crie...
# 10               62  https://raw.githubusercontent.com/PokeAPI/crie...
# 11              112  https://raw.githubusercontent.com/PokeAPI/crie...
# 12               64  https://raw.githubusercontent.com/PokeAPI/crie...
# 13               62  https://raw.githubusercontent.com/PokeAPI/crie...
# 14              112  https://raw.githubusercontent.com/PokeAPI/crie...
# 15               64  https://raw.githubusercontent.com/PokeAPI/crie...
# 16               62  https://raw.githubusercontent.com/PokeAPI/crie...
# 17              112  https://raw.githubusercontent.com/PokeAPI/crie...
# 18               64  https://raw.githubusercontent.com/PokeAPI/crie...
# 19               62  https://raw.githubusercontent.com/PokeAPI/crie...
# 20              112  https://raw.githubusercontent.com/PokeAPI/crie...
#
#                                         cries__legacy  height  id  is_default  \
# 0   https://raw.githubusercontent.com/PokeAPI/crie...       7   1        True
# 1   https://raw.githubusercontent.com/PokeAPI/crie...       6   4        True
# 2   https://raw.githubusercontent.com/PokeAPI/crie...       4  25        True
# 3   https://raw.githubusercontent.com/PokeAPI/crie...       7   1        True
# 4   https://raw.githubusercontent.com/PokeAPI/crie...       6   4        True
# 5   https://raw.githubusercontent.com/PokeAPI/crie...       4  25        True
# 6   https://raw.githubusercontent.com/PokeAPI/crie...       7   1        True
# 7   https://raw.githubusercontent.com/PokeAPI/crie...       6   4        True
# 8   https://raw.githubusercontent.com/PokeAPI/crie...       4  25        True
# 9   https://raw.githubusercontent.com/PokeAPI/crie...       7   1        True
# 10  https://raw.githubusercontent.com/PokeAPI/crie...       6   4        True
# 11  https://raw.githubusercontent.com/PokeAPI/crie...       4  25        True
# 12  https://raw.githubusercontent.com/PokeAPI/crie...       7   1        True
# 13  https://raw.githubusercontent.com/PokeAPI/crie...       6   4        True
# 14  https://raw.githubusercontent.com/PokeAPI/crie...       4  25        True
# 15  https://raw.githubusercontent.com/PokeAPI/crie...       7   1        True
# 16  https://raw.githubusercontent.com/PokeAPI/crie...       6   4        True
# 17  https://raw.githubusercontent.com/PokeAPI/crie...       4  25        True
# 18  https://raw.githubusercontent.com/PokeAPI/crie...       7   1        True
# 19  https://raw.githubusercontent.com/PokeAPI/crie...       6   4        True
# 20  https://raw.githubusercontent.com/PokeAPI/crie...       4  25        True
#
#                            location_area_encounters        name  order  \
# 0    https://pokeapi.co/api/v2/pokemon/1/encounters   bulbasaur      1
# 1    https://pokeapi.co/api/v2/pokemon/4/encounters  charmander      5
# 2   https://pokeapi.co/api/v2/pokemon/25/encounters     pikachu     35
# 3    https://pokeapi.co/api/v2/pokemon/1/encounters   bulbasaur      1
# 4    https://pokeapi.co/api/v2/pokemon/4/encounters  charmander      5
# 5   https://pokeapi.co/api/v2/pokemon/25/encounters     pikachu     35
# 6    https://pokeapi.co/api/v2/pokemon/1/encounters   bulbasaur      1
# 7    https://pokeapi.co/api/v2/pokemon/4/encounters  charmander      5
# 8   https://pokeapi.co/api/v2/pokemon/25/encounters     pikachu     35
# 9    https://pokeapi.co/api/v2/pokemon/1/encounters   bulbasaur      1
# 10   https://pokeapi.co/api/v2/pokemon/4/encounters  charmander      5
# 11  https://pokeapi.co/api/v2/pokemon/25/encounters     pikachu     35
# 12   https://pokeapi.co/api/v2/pokemon/1/encounters   bulbasaur      1
# 13   https://pokeapi.co/api/v2/pokemon/4/encounters  charmander      5
# 14  https://pokeapi.co/api/v2/pokemon/25/encounters     pikachu     35
# 15   https://pokeapi.co/api/v2/pokemon/1/encounters   bulbasaur      1
# 16   https://pokeapi.co/api/v2/pokemon/4/encounters  charmander      5
# 17  https://pokeapi.co/api/v2/pokemon/25/encounters     pikachu     35
# 18   https://pokeapi.co/api/v2/pokemon/1/encounters   bulbasaur      1
# 19   https://pokeapi.co/api/v2/pokemon/4/encounters  charmander      5
# 20  https://pokeapi.co/api/v2/pokemon/25/encounters     pikachu     35
#
#    species__name  ...  \
# 0      bulbasaur  ...
# 1     charmander  ...
# 2        pikachu  ...
# 3      bulbasaur  ...
# 4     charmander  ...
# 5        pikachu  ...
# 6      bulbasaur  ...
# 7     charmander  ...
# 8        pikachu  ...
# 9      bulbasaur  ...
# 10    charmander  ...
# 11       pikachu  ...
# 12     bulbasaur  ...
# 13    charmander  ...
# 14       pikachu  ...
# 15     bulbasaur  ...
# 16    charmander  ...
# 17       pikachu  ...
# 18     bulbasaur  ...
# 19    charmander  ...
# 20       pikachu  ...
#
#    sprites__versions__generation_v__black_white__back_shiny_female  \
# 0                                                None
# 1                                                None
# 2   https://raw.githubusercontent.com/PokeAPI/spri...
# 3                                                None
# 4                                                None
# 5   https://raw.githubusercontent.com/PokeAPI/spri...
# 6                                                None
# 7                                                None
# 8   https://raw.githubusercontent.com/PokeAPI/spri...
# 9                                                None
# 10                                               None
# 11  https://raw.githubusercontent.com/PokeAPI/spri...
# 12                                               None
# 13                                               None
# 14  https://raw.githubusercontent.com/PokeAPI/spri...
# 15                                               None
# 16                                               None
# 17  https://raw.githubusercontent.com/PokeAPI/spri...
# 18                                               None
# 19                                               None
# 20  https://raw.githubusercontent.com/PokeAPI/spri...
#
#    sprites__versions__generation_v__black_white__front_female  \
# 0                                                None
# 1                                                None
# 2   https://raw.githubusercontent.com/PokeAPI/spri...
# 3                                                None
# 4                                                None
# 5   https://raw.githubusercontent.com/PokeAPI/spri...
# 6                                                None
# 7                                                None
# 8   https://raw.githubusercontent.com/PokeAPI/spri...
# 9                                                None
# 10                                               None
# 11  https://raw.githubusercontent.com/PokeAPI/spri...
# 12                                               None
# 13                                               None
# 14  https://raw.githubusercontent.com/PokeAPI/spri...
# 15                                               None
# 16                                               None
# 17  https://raw.githubusercontent.com/PokeAPI/spri...
# 18                                               None
# 19                                               None
# 20  https://raw.githubusercontent.com/PokeAPI/spri...
#
#    sprites__versions__generation_v__black_white__front_shiny_female  \
# 0                                                None
# 1                                                None
# 2   https://raw.githubusercontent.com/PokeAPI/spri...
# 3                                                None
# 4                                                None
# 5   https://raw.githubusercontent.com/PokeAPI/spri...
# 6                                                None
# 7                                                None
# 8   https://raw.githubusercontent.com/PokeAPI/spri...
# 9                                                None
# 10                                               None
# 11  https://raw.githubusercontent.com/PokeAPI/spri...
# 12                                               None
# 13                                               None
# 14  https://raw.githubusercontent.com/PokeAPI/spri...
# 15                                               None
# 16                                               None
# 17  https://raw.githubusercontent.com/PokeAPI/spri...
# 18                                               None
# 19                                               None
# 20  https://raw.githubusercontent.com/PokeAPI/spri...
#
#    sprites__versions__generation_vi__omegaruby_alphasapphire__front_female  \
# 0                                                None
# 1                                                None
# 2   https://raw.githubusercontent.com/PokeAPI/spri...
# 3                                                None
# 4                                                None
# 5   https://raw.githubusercontent.com/PokeAPI/spri...
# 6                                                None
# 7                                                None
# 8   https://raw.githubusercontent.com/PokeAPI/spri...
# 9                                                None
# 10                                               None
# 11  https://raw.githubusercontent.com/PokeAPI/spri...
# 12                                               None
# 13                                               None
# 14  https://raw.githubusercontent.com/PokeAPI/spri...
# 15                                               None
# 16                                               None
# 17  https://raw.githubusercontent.com/PokeAPI/spri...
# 18                                               None
# 19                                               None
# 20  https://raw.githubusercontent.com/PokeAPI/spri...
#
#    sprites__versions__generation_vi__omegaruby_alphasapphire__front_shiny_female  \
# 0                                                None
# 1                                                None
# 2   https://raw.githubusercontent.com/PokeAPI/spri...
# 3                                                None
# 4                                                None
# 5   https://raw.githubusercontent.com/PokeAPI/spri...
# 6                                                None
# 7                                                None
# 8   https://raw.githubusercontent.com/PokeAPI/spri...
# 9                                                None
# 10                                               None
# 11  https://raw.githubusercontent.com/PokeAPI/spri...
# 12                                               None
# 13                                               None
# 14  https://raw.githubusercontent.com/PokeAPI/spri...
# 15                                               None
# 16                                               None
# 17  https://raw.githubusercontent.com/PokeAPI/spri...
# 18                                               None
# 19                                               None
# 20  https://raw.githubusercontent.com/PokeAPI/spri...
#
#    sprites__versions__generation_vi__x_y__front_female  \
# 0                                                None
# 1                                                None
# 2   https://raw.githubusercontent.com/PokeAPI/spri...
# 3                                                None
# 4                                                None
# 5   https://raw.githubusercontent.com/PokeAPI/spri...
# 6                                                None
# 7                                                None
# 8   https://raw.githubusercontent.com/PokeAPI/spri...
# 9                                                None
# 10                                               None
# 11  https://raw.githubusercontent.com/PokeAPI/spri...
# 12                                               None
# 13                                               None
# 14  https://raw.githubusercontent.com/PokeAPI/spri...
# 15                                               None
# 16                                               None
# 17  https://raw.githubusercontent.com/PokeAPI/spri...
# 18                                               None
# 19                                               None
# 20  https://raw.githubusercontent.com/PokeAPI/spri...
#
#    sprites__versions__generation_vi__x_y__front_shiny_female  \
# 0                                                None
# 1                                                None
# 2   https://raw.githubusercontent.com/PokeAPI/spri...
# 3                                                None
# 4                                                None
# 5   https://raw.githubusercontent.com/PokeAPI/spri...
# 6                                                None
# 7                                                None
# 8   https://raw.githubusercontent.com/PokeAPI/spri...
# 9                                                None
# 10                                               None
# 11  https://raw.githubusercontent.com/PokeAPI/spri...
# 12                                               None
# 13                                               None
# 14  https://raw.githubusercontent.com/PokeAPI/spri...
# 15                                               None
# 16                                               None
# 17  https://raw.githubusercontent.com/PokeAPI/spri...
# 18                                               None
# 19                                               None
# 20  https://raw.githubusercontent.com/PokeAPI/spri...
#
#    sprites__versions__generation_vii__ultra_sun_ultra_moon__front_female  \
# 0                                                None
# 1                                                None
# 2   https://raw.githubusercontent.com/PokeAPI/spri...
# 3                                                None
# 4                                                None
# 5   https://raw.githubusercontent.com/PokeAPI/spri...
# 6                                                None
# 7                                                None
# 8   https://raw.githubusercontent.com/PokeAPI/spri...
# 9                                                None
# 10                                               None
# 11  https://raw.githubusercontent.com/PokeAPI/spri...
# 12                                               None
# 13                                               None
# 14  https://raw.githubusercontent.com/PokeAPI/spri...
# 15                                               None
# 16                                               None
# 17  https://raw.githubusercontent.com/PokeAPI/spri...
# 18                                               None
# 19                                               None
# 20  https://raw.githubusercontent.com/PokeAPI/spri...
#
#    sprites__versions__generation_vii__ultra_sun_ultra_moon__front_shiny_female  \
# 0                                                None
# 1                                                None
# 2   https://raw.githubusercontent.com/PokeAPI/spri...
# 3                                                None
# 4                                                None
# 5   https://raw.githubusercontent.com/PokeAPI/spri...
# 6                                                None
# 7                                                None
# 8   https://raw.githubusercontent.com/PokeAPI/spri...
# 9                                                None
# 10                                               None
# 11  https://raw.githubusercontent.com/PokeAPI/spri...
# 12                                               None
# 13                                               None
# 14  https://raw.githubusercontent.com/PokeAPI/spri...
# 15                                               None
# 16                                               None
# 17  https://raw.githubusercontent.com/PokeAPI/spri...
# 18                                               None
# 19                                               None
# 20  https://raw.githubusercontent.com/PokeAPI/spri...
#
#    sprites__versions__generation_viii__icons__front_female
# 0                                                None
# 1                                                None
# 2   https://raw.githubusercontent.com/PokeAPI/spri...
# 3                                                None
# 4                                                None
# 5   https://raw.githubusercontent.com/PokeAPI/spri...
# 6                                                None
# 7                                                None
# 8   https://raw.githubusercontent.com/PokeAPI/spri...
# 9                                                None
# 10                                               None
# 11  https://raw.githubusercontent.com/PokeAPI/spri...
# 12                                               None
# 13                                               None
# 14  https://raw.githubusercontent.com/PokeAPI/spri...
# 15                                               None
# 16                                               None
# 17  https://raw.githubusercontent.com/PokeAPI/spri...
# 18                                               None
# 19                                               None
# 20  https://raw.githubusercontent.com/PokeAPI/spri...
#
# [21 rows x 131 columns]

# %%
pipeline.dataset(dataset_type="default").detailed_info.df().columns
# Out:
# Index(['base_experience', 'cries__latest', 'cries__legacy', 'height', 'id',
#        'is_default', 'location_area_encounters', 'name', 'order',
#        'species__name',
#        ...
#        'sprites__versions__generation_v__black_white__back_shiny_female',
#        'sprites__versions__generation_v__black_white__front_female',
#        'sprites__versions__generation_v__black_white__front_shiny_female',
#        'sprites__versions__generation_vi__omegaruby_alphasapphire__front_female',
#        'sprites__versions__generation_vi__omegaruby_alphasapphire__front_shiny_female',
#        'sprites__versions__generation_vi__x_y__front_female',
#        'sprites__versions__generation_vi__x_y__front_shiny_female',
#        'sprites__versions__generation_vii__ultra_sun_ultra_moon__front_female',
#        'sprites__versions__generation_vii__ultra_sun_ultra_moon__front_shiny_female',
#        'sprites__versions__generation_viii__icons__front_female'],
#       dtype='object', length=131)

# %% [markdown]
# Alternatively, we could do:

# %%
@dlt.resource(table_name='pokemon')
def my_dict_list():
    yield from data # <--- This would yield one item at a time


@dlt.transformer(data_from=my_dict_list, table_name='detailed_info')
def details(data_item): # <--- Transformer receives one item at a time
    id = data_item["id"]
    url = f"https://pokeapi.co/api/v2/pokemon/{id}"
    response = requests.get(url)
    details = response.json()

    yield details


load_info = pipeline.run(details())
print(load_info)
# Out:
# Pipeline resource_source_new load step completed in 0.83 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset all_data
# The duckdb destination used duckdb:////content/resource_source_new.duckdb location to store data
# Load package 1735261721.9444127 is LOADED and contains no failed jobs

# %% [markdown]
# You can also use pipe instead of `data_from`, this is useful when you want to apply `dlt.transformer` to multiple `dlt.resources`:

# %%
load_info = pipeline.run(my_dict_list | details)

# %% [markdown]
# Check the loaded data:

# %%
# Query the 'detailed_info' table and convert the result to a DataFrame
pipeline.dataset(dataset_type="default").detailed_info.df()
# Out:
#     base_experience                                      cries__latest  \
# 0                64  https://raw.githubusercontent.com/PokeAPI/crie...
# 1                62  https://raw.githubusercontent.com/PokeAPI/crie...
# 2               112  https://raw.githubusercontent.com/PokeAPI/crie...
# 3                64  https://raw.githubusercontent.com/PokeAPI/crie...
# 4                62  https://raw.githubusercontent.com/PokeAPI/crie...
# 5               112  https://raw.githubusercontent.com/PokeAPI/crie...
# 6                64  https://raw.githubusercontent.com/PokeAPI/crie...
# 7                62  https://raw.githubusercontent.com/PokeAPI/crie...
# 8               112  https://raw.githubusercontent.com/PokeAPI/crie...
# 9                64  https://raw.githubusercontent.com/PokeAPI/crie...
# 10               62  https://raw.githubusercontent.com/PokeAPI/crie...
# 11              112  https://raw.githubusercontent.com/PokeAPI/crie...
# 12               64  https://raw.githubusercontent.com/PokeAPI/crie...
# 13               62  https://raw.githubusercontent.com/PokeAPI/crie...
# 14              112  https://raw.githubusercontent.com/PokeAPI/crie...
# 15               64  https://raw.githubusercontent.com/PokeAPI/crie...
# 16               62  https://raw.githubusercontent.com/PokeAPI/crie...
# 17              112  https://raw.githubusercontent.com/PokeAPI/crie...
# 18               64  https://raw.githubusercontent.com/PokeAPI/crie...
# 19               62  https://raw.githubusercontent.com/PokeAPI/crie...
# 20              112  https://raw.githubusercontent.com/PokeAPI/crie...
# 21               64  https://raw.githubusercontent.com/PokeAPI/crie...
# 22               62  https://raw.githubusercontent.com/PokeAPI/crie...
# 23              112  https://raw.githubusercontent.com/PokeAPI/crie...
# 24               64  https://raw.githubusercontent.com/PokeAPI/crie...
# 25               62  https://raw.githubusercontent.com/PokeAPI/crie...
# 26              112  https://raw.githubusercontent.com/PokeAPI/crie...
#
#                                         cries__legacy  height  id  is_default  \
# 0   https://raw.githubusercontent.com/PokeAPI/crie...       7   1        True
# 1   https://raw.githubusercontent.com/PokeAPI/crie...       6   4        True
# 2   https://raw.githubusercontent.com/PokeAPI/crie...       4  25        True
# 3   https://raw.githubusercontent.com/PokeAPI/crie...       7   1        True
# 4   https://raw.githubusercontent.com/PokeAPI/crie...       6   4        True
# 5   https://raw.githubusercontent.com/PokeAPI/crie...       4  25        True
# 6   https://raw.githubusercontent.com/PokeAPI/crie...       7   1        True
# 7   https://raw.githubusercontent.com/PokeAPI/crie...       6   4        True
# 8   https://raw.githubusercontent.com/PokeAPI/crie...       4  25        True
# 9   https://raw.githubusercontent.com/PokeAPI/crie...       7   1        True
# 10  https://raw.githubusercontent.com/PokeAPI/crie...       6   4        True
# 11  https://raw.githubusercontent.com/PokeAPI/crie...       4  25        True
# 12  https://raw.githubusercontent.com/PokeAPI/crie...       7   1        True
# 13  https://raw.githubusercontent.com/PokeAPI/crie...       6   4        True
# 14  https://raw.githubusercontent.com/PokeAPI/crie...       4  25        True
# 15  https://raw.githubusercontent.com/PokeAPI/crie...       7   1        True
# 16  https://raw.githubusercontent.com/PokeAPI/crie...       6   4        True
# 17  https://raw.githubusercontent.com/PokeAPI/crie...       4  25        True
# 18  https://raw.githubusercontent.com/PokeAPI/crie...       7   1        True
# 19  https://raw.githubusercontent.com/PokeAPI/crie...       6   4        True
# 20  https://raw.githubusercontent.com/PokeAPI/crie...       4  25        True
# 21  https://raw.githubusercontent.com/PokeAPI/crie...       7   1        True
# 22  https://raw.githubusercontent.com/PokeAPI/crie...       6   4        True
# 23  https://raw.githubusercontent.com/PokeAPI/crie...       4  25        True
# 24  https://raw.githubusercontent.com/PokeAPI/crie...       7   1        True
# 25  https://raw.githubusercontent.com/PokeAPI/crie...       6   4        True
# 26  https://raw.githubusercontent.com/PokeAPI/crie...       4  25        True
#
#                            location_area_encounters        name  order  \
# 0    https://pokeapi.co/api/v2/pokemon/1/encounters   bulbasaur      1
# 1    https://pokeapi.co/api/v2/pokemon/4/encounters  charmander      5
# 2   https://pokeapi.co/api/v2/pokemon/25/encounters     pikachu     35
# 3    https://pokeapi.co/api/v2/pokemon/1/encounters   bulbasaur      1
# 4    https://pokeapi.co/api/v2/pokemon/4/encounters  charmander      5
# 5   https://pokeapi.co/api/v2/pokemon/25/encounters     pikachu     35
# 6    https://pokeapi.co/api/v2/pokemon/1/encounters   bulbasaur      1
# 7    https://pokeapi.co/api/v2/pokemon/4/encounters  charmander      5
# 8   https://pokeapi.co/api/v2/pokemon/25/encounters     pikachu     35
# 9    https://pokeapi.co/api/v2/pokemon/1/encounters   bulbasaur      1
# 10   https://pokeapi.co/api/v2/pokemon/4/encounters  charmander      5
# 11  https://pokeapi.co/api/v2/pokemon/25/encounters     pikachu     35
# 12   https://pokeapi.co/api/v2/pokemon/1/encounters   bulbasaur      1
# 13   https://pokeapi.co/api/v2/pokemon/4/encounters  charmander      5
# 14  https://pokeapi.co/api/v2/pokemon/25/encounters     pikachu     35
# 15   https://pokeapi.co/api/v2/pokemon/1/encounters   bulbasaur      1
# 16   https://pokeapi.co/api/v2/pokemon/4/encounters  charmander      5
# 17  https://pokeapi.co/api/v2/pokemon/25/encounters     pikachu     35
# 18   https://pokeapi.co/api/v2/pokemon/1/encounters   bulbasaur      1
# 19   https://pokeapi.co/api/v2/pokemon/4/encounters  charmander      5
# 20  https://pokeapi.co/api/v2/pokemon/25/encounters     pikachu     35
# 21   https://pokeapi.co/api/v2/pokemon/1/encounters   bulbasaur      1
# 22   https://pokeapi.co/api/v2/pokemon/4/encounters  charmander      5
# 23  https://pokeapi.co/api/v2/pokemon/25/encounters     pikachu     35
# 24   https://pokeapi.co/api/v2/pokemon/1/encounters   bulbasaur      1
# 25   https://pokeapi.co/api/v2/pokemon/4/encounters  charmander      5
# 26  https://pokeapi.co/api/v2/pokemon/25/encounters     pikachu     35
#
#    species__name  ...  \
# 0      bulbasaur  ...
# 1     charmander  ...
# 2        pikachu  ...
# 3      bulbasaur  ...
# 4     charmander  ...
# 5        pikachu  ...
# 6      bulbasaur  ...
# 7     charmander  ...
# 8        pikachu  ...
# 9      bulbasaur  ...
# 10    charmander  ...
# 11       pikachu  ...
# 12     bulbasaur  ...
# 13    charmander  ...
# 14       pikachu  ...
# 15     bulbasaur  ...
# 16    charmander  ...
# 17       pikachu  ...
# 18     bulbasaur  ...
# 19    charmander  ...
# 20       pikachu  ...
# 21     bulbasaur  ...
# 22    charmander  ...
# 23       pikachu  ...
# 24     bulbasaur  ...
# 25    charmander  ...
# 26       pikachu  ...
#
#    sprites__versions__generation_v__black_white__back_shiny_female  \
# 0                                                None
# 1                                                None
# 2   https://raw.githubusercontent.com/PokeAPI/spri...
# 3                                                None
# 4                                                None
# 5   https://raw.githubusercontent.com/PokeAPI/spri...
# 6                                                None
# 7                                                None
# 8   https://raw.githubusercontent.com/PokeAPI/spri...
# 9                                                None
# 10                                               None
# 11  https://raw.githubusercontent.com/PokeAPI/spri...
# 12                                               None
# 13                                               None
# 14  https://raw.githubusercontent.com/PokeAPI/spri...
# 15                                               None
# 16                                               None
# 17  https://raw.githubusercontent.com/PokeAPI/spri...
# 18                                               None
# 19                                               None
# 20  https://raw.githubusercontent.com/PokeAPI/spri...
# 21                                               None
# 22                                               None
# 23  https://raw.githubusercontent.com/PokeAPI/spri...
# 24                                               None
# 25                                               None
# 26  https://raw.githubusercontent.com/PokeAPI/spri...
#
#    sprites__versions__generation_v__black_white__front_female  \
# 0                                                None
# 1                                                None
# 2   https://raw.githubusercontent.com/PokeAPI/spri...
# 3                                                None
# 4                                                None
# 5   https://raw.githubusercontent.com/PokeAPI/spri...
# 6                                                None
# 7                                                None
# 8   https://raw.githubusercontent.com/PokeAPI/spri...
# 9                                                None
# 10                                               None
# 11  https://raw.githubusercontent.com/PokeAPI/spri...
# 12                                               None
# 13                                               None
# 14  https://raw.githubusercontent.com/PokeAPI/spri...
# 15                                               None
# 16                                               None
# 17  https://raw.githubusercontent.com/PokeAPI/spri...
# 18                                               None
# 19                                               None
# 20  https://raw.githubusercontent.com/PokeAPI/spri...
# 21                                               None
# 22                                               None
# 23  https://raw.githubusercontent.com/PokeAPI/spri...
# 24                                               None
# 25                                               None
# 26  https://raw.githubusercontent.com/PokeAPI/spri...
#
#    sprites__versions__generation_v__black_white__front_shiny_female  \
# 0                                                None
# 1                                                None
# 2   https://raw.githubusercontent.com/PokeAPI/spri...
# 3                                                None
# 4                                                None
# 5   https://raw.githubusercontent.com/PokeAPI/spri...
# 6                                                None
# 7                                                None
# 8   https://raw.githubusercontent.com/PokeAPI/spri...
# 9                                                None
# 10                                               None
# 11  https://raw.githubusercontent.com/PokeAPI/spri...
# 12                                               None
# 13                                               None
# 14  https://raw.githubusercontent.com/PokeAPI/spri...
# 15                                               None
# 16                                               None
# 17  https://raw.githubusercontent.com/PokeAPI/spri...
# 18                                               None
# 19                                               None
# 20  https://raw.githubusercontent.com/PokeAPI/spri...
# 21                                               None
# 22                                               None
# 23  https://raw.githubusercontent.com/PokeAPI/spri...
# 24                                               None
# 25                                               None
# 26  https://raw.githubusercontent.com/PokeAPI/spri...
#
#    sprites__versions__generation_vi__omegaruby_alphasapphire__front_female  \
# 0                                                None
# 1                                                None
# 2   https://raw.githubusercontent.com/PokeAPI/spri...
# 3                                                None
# 4                                                None
# 5   https://raw.githubusercontent.com/PokeAPI/spri...
# 6                                                None
# 7                                                None
# 8   https://raw.githubusercontent.com/PokeAPI/spri...
# 9                                                None
# 10                                               None
# 11  https://raw.githubusercontent.com/PokeAPI/spri...
# 12                                               None
# 13                                               None
# 14  https://raw.githubusercontent.com/PokeAPI/spri...
# 15                                               None
# 16                                               None
# 17  https://raw.githubusercontent.com/PokeAPI/spri...
# 18                                               None
# 19                                               None
# 20  https://raw.githubusercontent.com/PokeAPI/spri...
# 21                                               None
# 22                                               None
# 23  https://raw.githubusercontent.com/PokeAPI/spri...
# 24                                               None
# 25                                               None
# 26  https://raw.githubusercontent.com/PokeAPI/spri...
#
#    sprites__versions__generation_vi__omegaruby_alphasapphire__front_shiny_female  \
# 0                                                None
# 1                                                None
# 2   https://raw.githubusercontent.com/PokeAPI/spri...
# 3                                                None
# 4                                                None
# 5   https://raw.githubusercontent.com/PokeAPI/spri...
# 6                                                None
# 7                                                None
# 8   https://raw.githubusercontent.com/PokeAPI/spri...
# 9                                                None
# 10                                               None
# 11  https://raw.githubusercontent.com/PokeAPI/spri...
# 12                                               None
# 13                                               None
# 14  https://raw.githubusercontent.com/PokeAPI/spri...
# 15                                               None
# 16                                               None
# 17  https://raw.githubusercontent.com/PokeAPI/spri...
# 18                                               None
# 19                                               None
# 20  https://raw.githubusercontent.com/PokeAPI/spri...
# 21                                               None
# 22                                               None
# 23  https://raw.githubusercontent.com/PokeAPI/spri...
# 24                                               None
# 25                                               None
# 26  https://raw.githubusercontent.com/PokeAPI/spri...
#
#    sprites__versions__generation_vi__x_y__front_female  \
# 0                                                None
# 1                                                None
# 2   https://raw.githubusercontent.com/PokeAPI/spri...
# 3                                                None
# 4                                                None
# 5   https://raw.githubusercontent.com/PokeAPI/spri...
# 6                                                None
# 7                                                None
# 8   https://raw.githubusercontent.com/PokeAPI/spri...
# 9                                                None
# 10                                               None
# 11  https://raw.githubusercontent.com/PokeAPI/spri...
# 12                                               None
# 13                                               None
# 14  https://raw.githubusercontent.com/PokeAPI/spri...
# 15                                               None
# 16                                               None
# 17  https://raw.githubusercontent.com/PokeAPI/spri...
# 18                                               None
# 19                                               None
# 20  https://raw.githubusercontent.com/PokeAPI/spri...
# 21                                               None
# 22                                               None
# 23  https://raw.githubusercontent.com/PokeAPI/spri...
# 24                                               None
# 25                                               None
# 26  https://raw.githubusercontent.com/PokeAPI/spri...
#
#    sprites__versions__generation_vi__x_y__front_shiny_female  \
# 0                                                None
# 1                                                None
# 2   https://raw.githubusercontent.com/PokeAPI/spri...
# 3                                                None
# 4                                                None
# 5   https://raw.githubusercontent.com/PokeAPI/spri...
# 6                                                None
# 7                                                None
# 8   https://raw.githubusercontent.com/PokeAPI/spri...
# 9                                                None
# 10                                               None
# 11  https://raw.githubusercontent.com/PokeAPI/spri...
# 12                                               None
# 13                                               None
# 14  https://raw.githubusercontent.com/PokeAPI/spri...
# 15                                               None
# 16                                               None
# 17  https://raw.githubusercontent.com/PokeAPI/spri...
# 18                                               None
# 19                                               None
# 20  https://raw.githubusercontent.com/PokeAPI/spri...
# 21                                               None
# 22                                               None
# 23  https://raw.githubusercontent.com/PokeAPI/spri...
# 24                                               None
# 25                                               None
# 26  https://raw.githubusercontent.com/PokeAPI/spri...
#
#    sprites__versions__generation_vii__ultra_sun_ultra_moon__front_female  \
# 0                                                None
# 1                                                None
# 2   https://raw.githubusercontent.com/PokeAPI/spri...
# 3                                                None
# 4                                                None
# 5   https://raw.githubusercontent.com/PokeAPI/spri...
# 6                                                None
# 7                                                None
# 8   https://raw.githubusercontent.com/PokeAPI/spri...
# 9                                                None
# 10                                               None
# 11  https://raw.githubusercontent.com/PokeAPI/spri...
# 12                                               None
# 13                                               None
# 14  https://raw.githubusercontent.com/PokeAPI/spri...
# 15                                               None
# 16                                               None
# 17  https://raw.githubusercontent.com/PokeAPI/spri...
# 18                                               None
# 19                                               None
# 20  https://raw.githubusercontent.com/PokeAPI/spri...
# 21                                               None
# 22                                               None
# 23  https://raw.githubusercontent.com/PokeAPI/spri...
# 24                                               None
# 25                                               None
# 26  https://raw.githubusercontent.com/PokeAPI/spri...
#
#    sprites__versions__generation_vii__ultra_sun_ultra_moon__front_shiny_female  \
# 0                                                None
# 1                                                None
# 2   https://raw.githubusercontent.com/PokeAPI/spri...
# 3                                                None
# 4                                                None
# 5   https://raw.githubusercontent.com/PokeAPI/spri...
# 6                                                None
# 7                                                None
# 8   https://raw.githubusercontent.com/PokeAPI/spri...
# 9                                                None
# 10                                               None
# 11  https://raw.githubusercontent.com/PokeAPI/spri...
# 12                                               None
# 13                                               None
# 14  https://raw.githubusercontent.com/PokeAPI/spri...
# 15                                               None
# 16                                               None
# 17  https://raw.githubusercontent.com/PokeAPI/spri...
# 18                                               None
# 19                                               None
# 20  https://raw.githubusercontent.com/PokeAPI/spri...
# 21                                               None
# 22                                               None
# 23  https://raw.githubusercontent.com/PokeAPI/spri...
# 24                                               None
# 25                                               None
# 26  https://raw.githubusercontent.com/PokeAPI/spri...
#
#    sprites__versions__generation_viii__icons__front_female
# 0                                                None
# 1                                                None
# 2   https://raw.githubusercontent.com/PokeAPI/spri...
# 3                                                None
# 4                                                None
# 5   https://raw.githubusercontent.com/PokeAPI/spri...
# 6                                                None
# 7                                                None
# 8   https://raw.githubusercontent.com/PokeAPI/spri...
# 9                                                None
# 10                                               None
# 11  https://raw.githubusercontent.com/PokeAPI/spri...
# 12                                               None
# 13                                               None
# 14  https://raw.githubusercontent.com/PokeAPI/spri...
# 15                                               None
# 16                                               None
# 17  https://raw.githubusercontent.com/PokeAPI/spri...
# 18                                               None
# 19                                               None
# 20  https://raw.githubusercontent.com/PokeAPI/spri...
# 21                                               None
# 22                                               None
# 23  https://raw.githubusercontent.com/PokeAPI/spri...
# 24                                               None
# 25                                               None
# 26  https://raw.githubusercontent.com/PokeAPI/spri...
#
# [27 rows x 131 columns]

# %% [markdown]
# ---
# ## **Reduce the nesting level of generated tables**
# You can limit how deep dlt goes when generating nested tables and flattening dicts into columns. By default, the library will descend and generate nested tables for all nested lists, without limit.
#
# You can set nesting level for all resources on the source level:
#
# ```python
# @dlt.source(max_table_nesting=1)
# def all_data():
#   return my_df, get_genome_data, get_pokemon
# ```
#
# or for each resource separately:
#
# ```python
# @dlt.resource(table_name='pokemon_new', max_table_nesting=1)
# def my_dict_list():
#     yield data
# ```
#
# In the example above, we want only 1 level of nested tables to be generated (so there are no nested tables of a nested table). Typical settings:
#
# * `max_table_nesting=0` will not generate nested tables and will not flatten dicts into columns at all. All nested data will be represented as JSON.
# * `max_table_nesting=1` will generate nested tables of root tables and nothing more. All nested data in nested tables will be represented as JSON.

# %% [markdown]
# ---
# ## **Exercise 1: Create a pipeline for GitHub API - repos endpoint**
#
# In this exercise, you'll build a dlt pipeline to fetch data from the GitHub REST API. The goal is to learn how to use `dlt.pipeline`, `dlt.resource`, and `dlt.source` to extract and load data into a destination.
#
# ## Instructions
#
# 1. **Explore the GitHub API**
#
#   Visit the [GitHub REST API Docs](https://docs.github.com/en/rest) to understand the endpoint to [list public repositories](https://docs.github.com/en/rest/repos/repos?apiVersion=2022-11-28) for an organization:
#
#   GET https://api.github.com/orgs/{org}/repos
#
# 2. **Build the Pipeline**
#
#   Write a script to:
#
#   * Fetch repositories for a **dlt-hub** organization.
#   * Use `dlt.resource` to define the data extraction logic.
#   * Combine all resources to a single `@dlt.source`.
#   * Load the data into a DuckDB database.
#
# 3. **Look at the data**
#
#   Use `duckdb` connection, `sql_client` or `pipeline.dataset()`.
#
# > **Note**: For this exercise you don't need to use Auth and Pagination.

# %% [markdown]
# Play with API using requests library:

# %%
import requests
response = requests.get("https://api.github.com/orgs/dlt-hub/repos")
response.json()[0]
# Out:
# {'id': 427664318,
#  'node_id': 'R_kgDOGX2jvg',
#  'name': 'rasa_semantic_schema',
#  'full_name': 'dlt-hub/rasa_semantic_schema',
#  'private': False,
#  'owner': {'login': 'dlt-hub',
#   'id': 89419010,
#   'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg5NDE5MDEw',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/dlt-hub',
#   'html_url': 'https://github.com/dlt-hub',
#   'followers_url': 'https://api.github.com/users/dlt-hub/followers',
#   'following_url': 'https://api.github.com/users/dlt-hub/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/dlt-hub/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/dlt-hub/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/dlt-hub/subscriptions',
#   'organizations_url': 'https://api.github.com/users/dlt-hub/orgs',
#   'repos_url': 'https://api.github.com/users/dlt-hub/repos',
#   'events_url': 'https://api.github.com/users/dlt-hub/events{/privacy}',
#   'received_events_url': 'https://api.github.com/users/dlt-hub/received_events',
#   'type': 'Organization',
#   'user_view_type': 'public',
#   'site_admin': False},
#  'html_url': 'https://github.com/dlt-hub/rasa_semantic_schema',
#  'description': None,
#  'fork': False,
#  'url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema',
#  'forks_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/forks',
#  'keys_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/keys{/key_id}',
#  'collaborators_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/collaborators{/collaborator}',
#  'teams_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/teams',
#  'hooks_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/hooks',
#  'issue_events_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/issues/events{/number}',
#  'events_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/events',
#  'assignees_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/assignees{/user}',
#  'branches_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/branches{/branch}',
#  'tags_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/tags',
#  'blobs_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/git/blobs{/sha}',
#  'git_tags_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/git/tags{/sha}',
#  'git_refs_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/git/refs{/sha}',
#  'trees_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/git/trees{/sha}',
#  'statuses_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/statuses/{sha}',
#  'languages_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/languages',
#  'stargazers_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/stargazers',
#  'contributors_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/contributors',
#  'subscribers_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/subscribers',
#  'subscription_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/subscription',
#  'commits_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/commits{/sha}',
#  'git_commits_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/git/commits{/sha}',
#  'comments_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/comments{/number}',
#  'issue_comment_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/issues/comments{/number}',
#  'contents_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/contents/{+path}',
#  'compare_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/compare/{base}...{head}',
#  'merges_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/merges',
#  'archive_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/{archive_format}{/ref}',
#  'downloads_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/downloads',
#  'issues_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/issues{/number}',
#  'pulls_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/pulls{/number}',
#  'milestones_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/milestones{/number}',
#  'notifications_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/notifications{?since,all,participating}',
#  'labels_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/labels{/name}',
#  'releases_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/releases{/id}',
#  'deployments_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/deployments',
#  'created_at': '2021-11-13T12:54:03Z',
#  'updated_at': '2022-09-20T16:59:33Z',
#  'pushed_at': '2023-07-06T15:07:12Z',
#  'git_url': 'git://github.com/dlt-hub/rasa_semantic_schema.git',
#  'ssh_url': 'git@github.com:dlt-hub/rasa_semantic_schema.git',
#  'clone_url': 'https://github.com/dlt-hub/rasa_semantic_schema.git',
#  'svn_url': 'https://github.com/dlt-hub/rasa_semantic_schema',
#  'homepage': None,
#  'size': 711,
#  'stargazers_count': 2,
#  'watchers_count': 2,
#  'language': 'Python',
#  'has_issues': True,
#  'has_projects': True,
#  'has_downloads': True,
#  'has_wiki': True,
#  'has_pages': False,
#  'has_discussions': False,
#  'forks_count': 0,
#  'mirror_url': None,
#  'archived': False,
#  'disabled': False,
#  'open_issues_count': 4,
#  'license': {'key': 'other',
#   'name': 'Other',
#   'spdx_id': 'NOASSERTION',
#   'url': None,
#   'node_id': 'MDc6TGljZW5zZTA='},
#  'allow_forking': True,
#  'is_template': False,
#  'web_commit_signoff_required': False,
#  'topics': [],
#  'visibility': 'public',
#  'forks': 0,
#  'open_issues': 4,
#  'watchers': 2,
#  'default_branch': 'master',
#  'permissions': {'admin': False,
#   'maintain': False,
#   'push': False,
#   'triage': False,
#   'pull': True}}

# %%
response = requests.get("https://api.github.com/orgs/dlt-hub/events")
response.json()[0]
# Out:
# {'id': '45104166203',
#  'type': 'WatchEvent',
#  'actor': {'id': 23615357,
#   'login': 'visionarylab',
#   'display_login': 'visionarylab',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/visionarylab',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/23615357?'},
#  'repo': {'id': 452221115,
#   'name': 'dlt-hub/dlt',
#   'url': 'https://api.github.com/repos/dlt-hub/dlt'},
#  'payload': {'action': 'started'},
#  'public': True,
#  'created_at': '2024-12-27T01:06:28Z',
#  'org': {'id': 89419010,
#   'login': 'dlt-hub',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/orgs/dlt-hub',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?'}}

# %% [markdown]
# In the code snippet below you will find an **example** for **events** endpoint:

# %%
import dlt


# Example resource
@dlt.resource
def github_events():
    url = f"https://api.github.com/orgs/dlt-hub/events"
    response = requests.get(url)
    yield response.json()


# here is your code
@dlt.resource
def github_repos():
    # here is your code
    url = f"https://api.github.com/orgs/dlt-hub/repos"
    response = requests.get(url)
    yield response.json()




# Set pipeline name, destination, and dataset name
pipeline = dlt.pipeline(
    pipeline_name="github_pipeline",
    destination="duckdb",
    dataset_name="github_data"
)

load_info = pipeline.run(github_repos())
print(load_info)
# Out:
# Pipeline github_pipeline load step completed in 0.41 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset github_data
# The duckdb destination used duckdb:////content/github_pipeline.duckdb location to store data
# Load package 1735261728.8647943 is LOADED and contains no failed jobs

# %%
# List all table names from the database
with pipeline.sql_client() as client:
    with client.execute_query("SELECT * FROM github_repos") as table:
        print(table.df().head())
# Out:
#           id       node_id                                name  \
# 0  427664318  R_kgDOGX2jvg                rasa_semantic_schema
# 1  438622757  R_kgDOGiTaJQ                             .github
# 2  452221115  R_kgDOGvRYuw                                 dlt
# 3  462711174  R_kgDOG5Rphg  rasa_semantic_schema_customization
# 4  465315657  R_kgDOG7wnSQ                   metabase_data_api
#
#                                     full_name  private owner__login  \
# 0                dlt-hub/rasa_semantic_schema    False      dlt-hub
# 1                             dlt-hub/.github    False      dlt-hub
# 2                                 dlt-hub/dlt    False      dlt-hub
# 3  dlt-hub/rasa_semantic_schema_customization    False      dlt-hub
# 4                   dlt-hub/metabase_data_api    False      dlt-hub
#
#    owner__id                    owner__node_id  \
# 0   89419010  MDEyOk9yZ2FuaXphdGlvbjg5NDE5MDEw
# 1   89419010  MDEyOk9yZ2FuaXphdGlvbjg5NDE5MDEw
# 2   89419010  MDEyOk9yZ2FuaXphdGlvbjg5NDE5MDEw
# 3   89419010  MDEyOk9yZ2FuaXphdGlvbjg5NDE5MDEw
# 4   89419010  MDEyOk9yZ2FuaXphdGlvbjg5NDE5MDEw
#
#                                    owner__avatar_url owner__gravatar_id  ...  \
# 0  https://avatars.githubusercontent.com/u/894190...                     ...
# 1  https://avatars.githubusercontent.com/u/894190...                     ...
# 2  https://avatars.githubusercontent.com/u/894190...                     ...
# 3  https://avatars.githubusercontent.com/u/894190...                     ...
# 4  https://avatars.githubusercontent.com/u/894190...                     ...
#
#   permissions__admin permissions__maintain permissions__push  \
# 0              False                 False             False
# 1              False                 False             False
# 2              False                 False             False
# 3              False                 False             False
# 4              False                 False             False
#
#   permissions__triage permissions__pull        _dlt_load_id         _dlt_id  \
# 0               False              True  1735257705.2099562  2j02tZOJC3jwkQ
# 1               False              True  1735257705.2099562  kZijl9nVuCnLfg
# 2               False              True  1735257705.2099562  s8ebZAb6dPX2Mg
# 3               False              True  1735257705.2099562  HcY/hLIfdQ2Mvg
# 4               False              True  1735257705.2099562  8SoggJ8zHd/Xxw
#
#                                          description                 homepage  \
# 0                                               None                     None
# 1                                               None                     None
# 2  data load tool (dlt) is an open source Python ...  https://dlthub.com/docs
# 3  Template repository to customize and execute R...
# 4  Metabase data api python wrapper for notebooks...
#
#                                  license__url
# 0                                        None
# 1                                        None
# 2  https://api.github.com/licenses/apache-2.0
# 3                                        None
# 4         https://api.github.com/licenses/mit
#
# [5 rows x 106 columns]

# %%
pipeline.dataset(dataset_type="default").github_repos.df().head()
# Out:
#           id       node_id                                name  \
# 0  427664318  R_kgDOGX2jvg                rasa_semantic_schema
# 1  438622757  R_kgDOGiTaJQ                             .github
# 2  452221115  R_kgDOGvRYuw                                 dlt
# 3  462711174  R_kgDOG5Rphg  rasa_semantic_schema_customization
# 4  465315657  R_kgDOG7wnSQ                   metabase_data_api
#
#                                     full_name  private owner__login  \
# 0                dlt-hub/rasa_semantic_schema    False      dlt-hub
# 1                             dlt-hub/.github    False      dlt-hub
# 2                                 dlt-hub/dlt    False      dlt-hub
# 3  dlt-hub/rasa_semantic_schema_customization    False      dlt-hub
# 4                   dlt-hub/metabase_data_api    False      dlt-hub
#
#    owner__id                    owner__node_id  \
# 0   89419010  MDEyOk9yZ2FuaXphdGlvbjg5NDE5MDEw
# 1   89419010  MDEyOk9yZ2FuaXphdGlvbjg5NDE5MDEw
# 2   89419010  MDEyOk9yZ2FuaXphdGlvbjg5NDE5MDEw
# 3   89419010  MDEyOk9yZ2FuaXphdGlvbjg5NDE5MDEw
# 4   89419010  MDEyOk9yZ2FuaXphdGlvbjg5NDE5MDEw
#
#                                    owner__avatar_url owner__gravatar_id  ...  \
# 0  https://avatars.githubusercontent.com/u/894190...                     ...
# 1  https://avatars.githubusercontent.com/u/894190...                     ...
# 2  https://avatars.githubusercontent.com/u/894190...                     ...
# 3  https://avatars.githubusercontent.com/u/894190...                     ...
# 4  https://avatars.githubusercontent.com/u/894190...                     ...
#
#   permissions__admin permissions__maintain permissions__push  \
# 0              False                 False             False
# 1              False                 False             False
# 2              False                 False             False
# 3              False                 False             False
# 4              False                 False             False
#
#   permissions__triage permissions__pull        _dlt_load_id         _dlt_id  \
# 0               False              True  1735257705.2099562  2j02tZOJC3jwkQ
# 1               False              True  1735257705.2099562  kZijl9nVuCnLfg
# 2               False              True  1735257705.2099562  s8ebZAb6dPX2Mg
# 3               False              True  1735257705.2099562  HcY/hLIfdQ2Mvg
# 4               False              True  1735257705.2099562  8SoggJ8zHd/Xxw
#
#                                          description                 homepage  \
# 0                                               None                     None
# 1                                               None                     None
# 2  data load tool (dlt) is an open source Python ...  https://dlthub.com/docs
# 3  Template repository to customize and execute R...
# 4  Metabase data api python wrapper for notebooks...
#
#                                  license__url
# 0                                        None
# 1                                        None
# 2  https://api.github.com/licenses/apache-2.0
# 3                                        None
# 4         https://api.github.com/licenses/mit
#
# [5 rows x 106 columns]

# %% [markdown]
# ### Question
# How many columns has the `github_repos` table? Use `duckdb` connection, `sql_client` or `pipeline.dataset()`.

# %%
print("How many columns has the github_repos table?", len(pipeline.dataset(dataset_type="default").github_repos.df().columns))
# Out:
# How many columns has the github_repos table? 106

# %% [markdown]
# ## **Exercise 2: Create a pipeline for GitHub API - stargazers endpoint**
#
# Create a `dlt.transformer` for the "stargazers" endpoint
# https://api.github.com/repos/OWNER/REPO/stargazers for `dlt-hub` organization.
#
# Use `github_repos` resource as a main resource for the transformer:
# 1. Get all `dlt-hub` repositories.
# 2. Feed these repository names to dlt transformer and get all stargazers for all `dlt-hub` repositories.

# %%
# here is your code
@dlt.transformer(data_from=github_repos, table_name='github_stargazer')
def github_stargazer(items):
    # here is your code
    for item in items:

      print(f"Item: {item}\n")

      repo_name = item["name"]
      url = f"https://api.github.com/repos/dlt-hub/{repo_name}/stargazers"
      response = requests.get(url)
      stargazers = response.json()

      print(f"Stargazers: {stargazers}\n")
      yield stargazers


load_info = pipeline.run(github_stargazer())
print(load_info)
# Out:
# Item: {'id': 427664318, 'node_id': 'R_kgDOGX2jvg', 'name': 'rasa_semantic_schema', 'full_name': 'dlt-hub/rasa_semantic_schema', 'private': False, 'owner': {'login': 'dlt-hub', 'id': 89419010, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg5NDE5MDEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/dlt-hub', 'html_url': 'https://github.com/dlt-hub', 'followers_url': 'https://api.github.com/users/dlt-hub/followers', 'following_url': 'https://api.github.com/users/dlt-hub/following{/other_user}', 'gists_url': 'https://api.github.com/users/dlt-hub/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/dlt-hub/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/dlt-hub/subscriptions', 'organizations_url': 'https://api.github.com/users/dlt-hub/orgs', 'repos_url': 'https://api.github.com/users/dlt-hub/repos', 'events_url': 'https://api.github.com/users/dlt-hub/events{/privacy}', 'received_events_url': 'https://api.github.com/users/dlt-hub/received_events', 'type': 'Organization', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/dlt-hub/rasa_semantic_schema', 'description': None, 'fork': False, 'url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema', 'forks_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/forks', 'keys_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/teams', 'hooks_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/hooks', 'issue_events_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/issues/events{/number}', 'events_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/events', 'assignees_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/assignees{/user}', 'branches_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/branches{/branch}', 'tags_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/tags', 'blobs_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/languages', 'stargazers_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/stargazers', 'contributors_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/contributors', 'subscribers_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/subscribers', 'subscription_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/subscription', 'commits_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/contents/{+path}', 'compare_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/merges', 'archive_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema/downloads', 'issues_url': 'https://api.github.com/r ...
#
# Stargazers: [{'login': 'indam23', 'id': 32034278, 'node_id': 'MDQ6VXNlcjMyMDM0Mjc4', 'avatar_url': 'https://avatars.githubusercontent.com/u/32034278?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/indam23', 'html_url': 'https://github.com/indam23', 'followers_url': 'https://api.github.com/users/indam23/followers', 'following_url': 'https://api.github.com/users/indam23/following{/other_user}', 'gists_url': 'https://api.github.com/users/indam23/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/indam23/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/indam23/subscriptions', 'organizations_url': 'https://api.github.com/users/indam23/orgs', 'repos_url': 'https://api.github.com/users/indam23/repos', 'events_url': 'https://api.github.com/users/indam23/events{/privacy}', 'received_events_url': 'https://api.github.com/users/indam23/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'Ai-Yukino', 'id': 87879276, 'node_id': 'MDQ6VXNlcjg3ODc5Mjc2', 'avatar_url': 'https://avatars.githubusercontent.com/u/87879276?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/Ai-Yukino', 'html_url': 'https://github.com/Ai-Yukino', 'followers_url': 'https://api.github.com/users/Ai-Yukino/followers', 'following_url': 'https://api.github.com/users/Ai-Yukino/following{/other_user}', 'gists_url': 'https://api.github.com/users/Ai-Yukino/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/Ai-Yukino/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/Ai-Yukino/subscriptions', 'organizations_url': 'https://api.github.com/users/Ai-Yukino/orgs', 'repos_url': 'https://api.github.com/users/Ai-Yukino/repos', 'events_url': 'https://api.github.com/users/Ai-Yukino/events{/privacy}', 'received_events_url': 'https://api.github.com/users/Ai-Yukino/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}]
#
# Item: {'id': 438622757, 'node_id': 'R_kgDOGiTaJQ', 'name': '.github', 'full_name': 'dlt-hub/.github', 'private': False, 'owner': {'login': 'dlt-hub', 'id': 89419010, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg5NDE5MDEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/dlt-hub', 'html_url': 'https://github.com/dlt-hub', 'followers_url': 'https://api.github.com/users/dlt-hub/followers', 'following_url': 'https://api.github.com/users/dlt-hub/following{/other_user}', 'gists_url': 'https://api.github.com/users/dlt-hub/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/dlt-hub/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/dlt-hub/subscriptions', 'organizations_url': 'https://api.github.com/users/dlt-hub/orgs', 'repos_url': 'https://api.github.com/users/dlt-hub/repos', 'events_url': 'https://api.github.com/users/dlt-hub/events{/privacy}', 'received_events_url': 'https://api.github.com/users/dlt-hub/received_events', 'type': 'Organization', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/dlt-hub/.github', 'description': None, 'fork': False, 'url': 'https://api.github.com/repos/dlt-hub/.github', 'forks_url': 'https://api.github.com/repos/dlt-hub/.github/forks', 'keys_url': 'https://api.github.com/repos/dlt-hub/.github/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/dlt-hub/.github/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/dlt-hub/.github/teams', 'hooks_url': 'https://api.github.com/repos/dlt-hub/.github/hooks', 'issue_events_url': 'https://api.github.com/repos/dlt-hub/.github/issues/events{/number}', 'events_url': 'https://api.github.com/repos/dlt-hub/.github/events', 'assignees_url': 'https://api.github.com/repos/dlt-hub/.github/assignees{/user}', 'branches_url': 'https://api.github.com/repos/dlt-hub/.github/branches{/branch}', 'tags_url': 'https://api.github.com/repos/dlt-hub/.github/tags', 'blobs_url': 'https://api.github.com/repos/dlt-hub/.github/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/dlt-hub/.github/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/dlt-hub/.github/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/dlt-hub/.github/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/dlt-hub/.github/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/dlt-hub/.github/languages', 'stargazers_url': 'https://api.github.com/repos/dlt-hub/.github/stargazers', 'contributors_url': 'https://api.github.com/repos/dlt-hub/.github/contributors', 'subscribers_url': 'https://api.github.com/repos/dlt-hub/.github/subscribers', 'subscription_url': 'https://api.github.com/repos/dlt-hub/.github/subscription', 'commits_url': 'https://api.github.com/repos/dlt-hub/.github/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/dlt-hub/.github/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/dlt-hub/.github/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/dlt-hub/.github/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/dlt-hub/.github/contents/{+path}', 'compare_url': 'https://api.github.com/repos/dlt-hub/.github/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/dlt-hub/.github/merges', 'archive_url': 'https://api.github.com/repos/dlt-hub/.github/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/dlt-hub/.github/downloads', 'issues_url': 'https://api.github.com/repos/dlt-hub/.github/issues{/number}', 'pulls_url': 'https://api.github.com/repos/dlt-hub/.github/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/dlt-hub/.github/milestones{/number}', 'notifications_url': 'https://api.github.com/repos/dlt-hub/.github/notifications{?since,all,participating}', 'labels_url': 'https://api.github.com/repos/dlt-hub/.github/labels{/name}', 'releases_url': 'https://api.github.com/rep ...
#
# Stargazers: []
#
# Item: {'id': 452221115, 'node_id': 'R_kgDOGvRYuw', 'name': 'dlt', 'full_name': 'dlt-hub/dlt', 'private': False, 'owner': {'login': 'dlt-hub', 'id': 89419010, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg5NDE5MDEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/dlt-hub', 'html_url': 'https://github.com/dlt-hub', 'followers_url': 'https://api.github.com/users/dlt-hub/followers', 'following_url': 'https://api.github.com/users/dlt-hub/following{/other_user}', 'gists_url': 'https://api.github.com/users/dlt-hub/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/dlt-hub/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/dlt-hub/subscriptions', 'organizations_url': 'https://api.github.com/users/dlt-hub/orgs', 'repos_url': 'https://api.github.com/users/dlt-hub/repos', 'events_url': 'https://api.github.com/users/dlt-hub/events{/privacy}', 'received_events_url': 'https://api.github.com/users/dlt-hub/received_events', 'type': 'Organization', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/dlt-hub/dlt', 'description': 'data load tool (dlt) is an open source Python library that makes data loading easy 🛠️ ', 'fork': False, 'url': 'https://api.github.com/repos/dlt-hub/dlt', 'forks_url': 'https://api.github.com/repos/dlt-hub/dlt/forks', 'keys_url': 'https://api.github.com/repos/dlt-hub/dlt/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/dlt-hub/dlt/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/dlt-hub/dlt/teams', 'hooks_url': 'https://api.github.com/repos/dlt-hub/dlt/hooks', 'issue_events_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/events{/number}', 'events_url': 'https://api.github.com/repos/dlt-hub/dlt/events', 'assignees_url': 'https://api.github.com/repos/dlt-hub/dlt/assignees{/user}', 'branches_url': 'https://api.github.com/repos/dlt-hub/dlt/branches{/branch}', 'tags_url': 'https://api.github.com/repos/dlt-hub/dlt/tags', 'blobs_url': 'https://api.github.com/repos/dlt-hub/dlt/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/dlt-hub/dlt/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/dlt-hub/dlt/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/dlt-hub/dlt/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/dlt-hub/dlt/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/dlt-hub/dlt/languages', 'stargazers_url': 'https://api.github.com/repos/dlt-hub/dlt/stargazers', 'contributors_url': 'https://api.github.com/repos/dlt-hub/dlt/contributors', 'subscribers_url': 'https://api.github.com/repos/dlt-hub/dlt/subscribers', 'subscription_url': 'https://api.github.com/repos/dlt-hub/dlt/subscription', 'commits_url': 'https://api.github.com/repos/dlt-hub/dlt/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/dlt-hub/dlt/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/dlt-hub/dlt/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/dlt-hub/dlt/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/dlt-hub/dlt/contents/{+path}', 'compare_url': 'https://api.github.com/repos/dlt-hub/dlt/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/dlt-hub/dlt/merges', 'archive_url': 'https://api.github.com/repos/dlt-hub/dlt/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/dlt-hub/dlt/downloads', 'issues_url': 'https://api.github.com/repos/dlt-hub/dlt/issues{/number}', 'pulls_url': 'https://api.github.com/repos/dlt-hub/dlt/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/dlt-hub/dlt/milestones{/number}', 'notifications_url': 'https://api.github.com/repos/dlt-hub/dlt/notifications{?since,all,participating}', 'labels_url': 'https://api.github.com/repos/dlt-hub/dlt/labels{/name}', 'releases_url': 'https://api.github.com/repos/dlt-hub/dlt/releases{/id}', 'deployments_url': 'https://api.githu ...
#
# Stargazers: [{'login': 'lalitpagaria', 'id': 19303690, 'node_id': 'MDQ6VXNlcjE5MzAzNjkw', 'avatar_url': 'https://avatars.githubusercontent.com/u/19303690?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/lalitpagaria', 'html_url': 'https://github.com/lalitpagaria', 'followers_url': 'https://api.github.com/users/lalitpagaria/followers', 'following_url': 'https://api.github.com/users/lalitpagaria/following{/other_user}', 'gists_url': 'https://api.github.com/users/lalitpagaria/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/lalitpagaria/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/lalitpagaria/subscriptions', 'organizations_url': 'https://api.github.com/users/lalitpagaria/orgs', 'repos_url': 'https://api.github.com/users/lalitpagaria/repos', 'events_url': 'https://api.github.com/users/lalitpagaria/events{/privacy}', 'received_events_url': 'https://api.github.com/users/lalitpagaria/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'nikitavoloboev', 'id': 6391776, 'node_id': 'MDQ6VXNlcjYzOTE3NzY=', 'avatar_url': 'https://avatars.githubusercontent.com/u/6391776?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/nikitavoloboev', 'html_url': 'https://github.com/nikitavoloboev', 'followers_url': 'https://api.github.com/users/nikitavoloboev/followers', 'following_url': 'https://api.github.com/users/nikitavoloboev/following{/other_user}', 'gists_url': 'https://api.github.com/users/nikitavoloboev/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/nikitavoloboev/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/nikitavoloboev/subscriptions', 'organizations_url': 'https://api.github.com/users/nikitavoloboev/orgs', 'repos_url': 'https://api.github.com/users/nikitavoloboev/repos', 'events_url': 'https://api.github.com/users/nikitavoloboev/events{/privacy}', 'received_events_url': 'https://api.github.com/users/nikitavoloboev/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'gerrykou', 'id': 13572514, 'node_id': 'MDQ6VXNlcjEzNTcyNTE0', 'avatar_url': 'https://avatars.githubusercontent.com/u/13572514?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/gerrykou', 'html_url': 'https://github.com/gerrykou', 'followers_url': 'https://api.github.com/users/gerrykou/followers', 'following_url': 'https://api.github.com/users/gerrykou/following{/other_user}', 'gists_url': 'https://api.github.com/users/gerrykou/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/gerrykou/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/gerrykou/subscriptions', 'organizations_url': 'https://api.github.com/users/gerrykou/orgs', 'repos_url': 'https://api.github.com/users/gerrykou/repos', 'events_url': 'https://api.github.com/users/gerrykou/events{/privacy}', 'received_events_url': 'https://api.github.com/users/gerrykou/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'jdmonty', 'id': 3614077, 'node_id': 'MDQ6VXNlcjM2MTQwNzc=', 'avatar_url': 'https://avatars.githubusercontent.com/u/3614077?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/jdmonty', 'html_url': 'https://github.com/jdmonty', 'followers_url': 'https://api.github.com/users/jdmonty/followers', 'following_url': 'https://api.github.com/users/jdmonty/following{/other_user}', 'gists_url': 'https://api.github.com/users/jdmonty/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/jdmonty/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/jdmonty/subscriptions', 'organizations_url': 'https://api.github.com/users/jdmonty/orgs', 'repos_url': 'https://api.github.com/users/jdmonty/repos', 'events_url': 'https://api.github.com/users/jdmonty/events{/privacy}', 'received_events_url': 'https://api.github.com/users/jdmonty/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': Fal ...
#
# Item: {'id': 462711174, 'node_id': 'R_kgDOG5Rphg', 'name': 'rasa_semantic_schema_customization', 'full_name': 'dlt-hub/rasa_semantic_schema_customization', 'private': False, 'owner': {'login': 'dlt-hub', 'id': 89419010, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg5NDE5MDEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/dlt-hub', 'html_url': 'https://github.com/dlt-hub', 'followers_url': 'https://api.github.com/users/dlt-hub/followers', 'following_url': 'https://api.github.com/users/dlt-hub/following{/other_user}', 'gists_url': 'https://api.github.com/users/dlt-hub/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/dlt-hub/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/dlt-hub/subscriptions', 'organizations_url': 'https://api.github.com/users/dlt-hub/orgs', 'repos_url': 'https://api.github.com/users/dlt-hub/repos', 'events_url': 'https://api.github.com/users/dlt-hub/events{/privacy}', 'received_events_url': 'https://api.github.com/users/dlt-hub/received_events', 'type': 'Organization', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/dlt-hub/rasa_semantic_schema_customization', 'description': 'Template repository to customize and execute Rasa Semantic Schema DBT package', 'fork': False, 'url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema_customization', 'forks_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema_customization/forks', 'keys_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema_customization/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema_customization/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema_customization/teams', 'hooks_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema_customization/hooks', 'issue_events_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema_customization/issues/events{/number}', 'events_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema_customization/events', 'assignees_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema_customization/assignees{/user}', 'branches_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema_customization/branches{/branch}', 'tags_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema_customization/tags', 'blobs_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema_customization/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema_customization/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema_customization/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema_customization/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema_customization/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema_customization/languages', 'stargazers_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema_customization/stargazers', 'contributors_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema_customization/contributors', 'subscribers_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema_customization/subscribers', 'subscription_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema_customization/subscription', 'commits_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema_customization/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema_customization/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema_customization/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/dlt-hub/rasa_semantic_schema_customization/issues/comments{/number}', 'contents_url': 'https://api.github ...
#
# Stargazers: []
#
# Item: {'id': 465315657, 'node_id': 'R_kgDOG7wnSQ', 'name': 'metabase_data_api', 'full_name': 'dlt-hub/metabase_data_api', 'private': False, 'owner': {'login': 'dlt-hub', 'id': 89419010, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg5NDE5MDEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/dlt-hub', 'html_url': 'https://github.com/dlt-hub', 'followers_url': 'https://api.github.com/users/dlt-hub/followers', 'following_url': 'https://api.github.com/users/dlt-hub/following{/other_user}', 'gists_url': 'https://api.github.com/users/dlt-hub/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/dlt-hub/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/dlt-hub/subscriptions', 'organizations_url': 'https://api.github.com/users/dlt-hub/orgs', 'repos_url': 'https://api.github.com/users/dlt-hub/repos', 'events_url': 'https://api.github.com/users/dlt-hub/events{/privacy}', 'received_events_url': 'https://api.github.com/users/dlt-hub/received_events', 'type': 'Organization', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/dlt-hub/metabase_data_api', 'description': 'Metabase data api python wrapper for notebooks and automation', 'fork': False, 'url': 'https://api.github.com/repos/dlt-hub/metabase_data_api', 'forks_url': 'https://api.github.com/repos/dlt-hub/metabase_data_api/forks', 'keys_url': 'https://api.github.com/repos/dlt-hub/metabase_data_api/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/dlt-hub/metabase_data_api/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/dlt-hub/metabase_data_api/teams', 'hooks_url': 'https://api.github.com/repos/dlt-hub/metabase_data_api/hooks', 'issue_events_url': 'https://api.github.com/repos/dlt-hub/metabase_data_api/issues/events{/number}', 'events_url': 'https://api.github.com/repos/dlt-hub/metabase_data_api/events', 'assignees_url': 'https://api.github.com/repos/dlt-hub/metabase_data_api/assignees{/user}', 'branches_url': 'https://api.github.com/repos/dlt-hub/metabase_data_api/branches{/branch}', 'tags_url': 'https://api.github.com/repos/dlt-hub/metabase_data_api/tags', 'blobs_url': 'https://api.github.com/repos/dlt-hub/metabase_data_api/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/dlt-hub/metabase_data_api/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/dlt-hub/metabase_data_api/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/dlt-hub/metabase_data_api/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/dlt-hub/metabase_data_api/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/dlt-hub/metabase_data_api/languages', 'stargazers_url': 'https://api.github.com/repos/dlt-hub/metabase_data_api/stargazers', 'contributors_url': 'https://api.github.com/repos/dlt-hub/metabase_data_api/contributors', 'subscribers_url': 'https://api.github.com/repos/dlt-hub/metabase_data_api/subscribers', 'subscription_url': 'https://api.github.com/repos/dlt-hub/metabase_data_api/subscription', 'commits_url': 'https://api.github.com/repos/dlt-hub/metabase_data_api/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/dlt-hub/metabase_data_api/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/dlt-hub/metabase_data_api/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/dlt-hub/metabase_data_api/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/dlt-hub/metabase_data_api/contents/{+path}', 'compare_url': 'https://api.github.com/repos/dlt-hub/metabase_data_api/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/dlt-hub/metabase_data_api/merges', 'archive_url': 'https://api.github.com/repos/dlt-hub/metabase_data_api/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/dlt-hub/metabase_data_api/downloads', 'issues_url': 'https://api.github.com/repos/dlt-hub/metabase_data_api/issues{/n ...
#
# Stargazers: []
#
# Item: {'id': 526253602, 'node_id': 'R_kgDOH13-Ig', 'name': 'dlt-axie-infinity-demo', 'full_name': 'dlt-hub/dlt-axie-infinity-demo', 'private': False, 'owner': {'login': 'dlt-hub', 'id': 89419010, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg5NDE5MDEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/dlt-hub', 'html_url': 'https://github.com/dlt-hub', 'followers_url': 'https://api.github.com/users/dlt-hub/followers', 'following_url': 'https://api.github.com/users/dlt-hub/following{/other_user}', 'gists_url': 'https://api.github.com/users/dlt-hub/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/dlt-hub/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/dlt-hub/subscriptions', 'organizations_url': 'https://api.github.com/users/dlt-hub/orgs', 'repos_url': 'https://api.github.com/users/dlt-hub/repos', 'events_url': 'https://api.github.com/users/dlt-hub/events{/privacy}', 'received_events_url': 'https://api.github.com/users/dlt-hub/received_events', 'type': 'Organization', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/dlt-hub/dlt-axie-infinity-demo', 'description': 'DLT Pipeline Script to get Axie Infinity smart contracts data on Ronin Network into BigQuery/Redshift', 'fork': False, 'url': 'https://api.github.com/repos/dlt-hub/dlt-axie-infinity-demo', 'forks_url': 'https://api.github.com/repos/dlt-hub/dlt-axie-infinity-demo/forks', 'keys_url': 'https://api.github.com/repos/dlt-hub/dlt-axie-infinity-demo/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/dlt-hub/dlt-axie-infinity-demo/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/dlt-hub/dlt-axie-infinity-demo/teams', 'hooks_url': 'https://api.github.com/repos/dlt-hub/dlt-axie-infinity-demo/hooks', 'issue_events_url': 'https://api.github.com/repos/dlt-hub/dlt-axie-infinity-demo/issues/events{/number}', 'events_url': 'https://api.github.com/repos/dlt-hub/dlt-axie-infinity-demo/events', 'assignees_url': 'https://api.github.com/repos/dlt-hub/dlt-axie-infinity-demo/assignees{/user}', 'branches_url': 'https://api.github.com/repos/dlt-hub/dlt-axie-infinity-demo/branches{/branch}', 'tags_url': 'https://api.github.com/repos/dlt-hub/dlt-axie-infinity-demo/tags', 'blobs_url': 'https://api.github.com/repos/dlt-hub/dlt-axie-infinity-demo/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/dlt-hub/dlt-axie-infinity-demo/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/dlt-hub/dlt-axie-infinity-demo/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/dlt-hub/dlt-axie-infinity-demo/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/dlt-hub/dlt-axie-infinity-demo/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/dlt-hub/dlt-axie-infinity-demo/languages', 'stargazers_url': 'https://api.github.com/repos/dlt-hub/dlt-axie-infinity-demo/stargazers', 'contributors_url': 'https://api.github.com/repos/dlt-hub/dlt-axie-infinity-demo/contributors', 'subscribers_url': 'https://api.github.com/repos/dlt-hub/dlt-axie-infinity-demo/subscribers', 'subscription_url': 'https://api.github.com/repos/dlt-hub/dlt-axie-infinity-demo/subscription', 'commits_url': 'https://api.github.com/repos/dlt-hub/dlt-axie-infinity-demo/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/dlt-hub/dlt-axie-infinity-demo/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/dlt-hub/dlt-axie-infinity-demo/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/dlt-hub/dlt-axie-infinity-demo/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/dlt-hub/dlt-axie-infinity-demo/contents/{+path}', 'compare_url': 'https://api.github.com/repos/dlt-hub/dlt-axie-infinity-demo/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/dlt-hub/dlt-axie-infinity-demo/merges', 'archive_url': 'https://api.github.com/repos/dlt-hub/dlt-axie-inf ...
#
# Stargazers: []
#
# Item: {'id': 565936302, 'node_id': 'R_kgDOIbuArg', 'name': 'python-dlt-init-template', 'full_name': 'dlt-hub/python-dlt-init-template', 'private': False, 'owner': {'login': 'dlt-hub', 'id': 89419010, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg5NDE5MDEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/dlt-hub', 'html_url': 'https://github.com/dlt-hub', 'followers_url': 'https://api.github.com/users/dlt-hub/followers', 'following_url': 'https://api.github.com/users/dlt-hub/following{/other_user}', 'gists_url': 'https://api.github.com/users/dlt-hub/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/dlt-hub/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/dlt-hub/subscriptions', 'organizations_url': 'https://api.github.com/users/dlt-hub/orgs', 'repos_url': 'https://api.github.com/users/dlt-hub/repos', 'events_url': 'https://api.github.com/users/dlt-hub/events{/privacy}', 'received_events_url': 'https://api.github.com/users/dlt-hub/received_events', 'type': 'Organization', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/dlt-hub/python-dlt-init-template', 'description': None, 'fork': False, 'url': 'https://api.github.com/repos/dlt-hub/python-dlt-init-template', 'forks_url': 'https://api.github.com/repos/dlt-hub/python-dlt-init-template/forks', 'keys_url': 'https://api.github.com/repos/dlt-hub/python-dlt-init-template/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/dlt-hub/python-dlt-init-template/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/dlt-hub/python-dlt-init-template/teams', 'hooks_url': 'https://api.github.com/repos/dlt-hub/python-dlt-init-template/hooks', 'issue_events_url': 'https://api.github.com/repos/dlt-hub/python-dlt-init-template/issues/events{/number}', 'events_url': 'https://api.github.com/repos/dlt-hub/python-dlt-init-template/events', 'assignees_url': 'https://api.github.com/repos/dlt-hub/python-dlt-init-template/assignees{/user}', 'branches_url': 'https://api.github.com/repos/dlt-hub/python-dlt-init-template/branches{/branch}', 'tags_url': 'https://api.github.com/repos/dlt-hub/python-dlt-init-template/tags', 'blobs_url': 'https://api.github.com/repos/dlt-hub/python-dlt-init-template/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/dlt-hub/python-dlt-init-template/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/dlt-hub/python-dlt-init-template/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/dlt-hub/python-dlt-init-template/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/dlt-hub/python-dlt-init-template/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/dlt-hub/python-dlt-init-template/languages', 'stargazers_url': 'https://api.github.com/repos/dlt-hub/python-dlt-init-template/stargazers', 'contributors_url': 'https://api.github.com/repos/dlt-hub/python-dlt-init-template/contributors', 'subscribers_url': 'https://api.github.com/repos/dlt-hub/python-dlt-init-template/subscribers', 'subscription_url': 'https://api.github.com/repos/dlt-hub/python-dlt-init-template/subscription', 'commits_url': 'https://api.github.com/repos/dlt-hub/python-dlt-init-template/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/dlt-hub/python-dlt-init-template/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/dlt-hub/python-dlt-init-template/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/dlt-hub/python-dlt-init-template/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/dlt-hub/python-dlt-init-template/contents/{+path}', 'compare_url': 'https://api.github.com/repos/dlt-hub/python-dlt-init-template/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/dlt-hub/python-dlt-init-template/merges', 'archive_url': 'https://api.github.com/repos/dlt-hub/python-dlt-init-template/{archive_format}{/ref}', ...
#
# Stargazers: []
#
# Item: {'id': 571809083, 'node_id': 'R_kgDOIhUdOw', 'name': 'dlt-deploy-template', 'full_name': 'dlt-hub/dlt-deploy-template', 'private': False, 'owner': {'login': 'dlt-hub', 'id': 89419010, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg5NDE5MDEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/dlt-hub', 'html_url': 'https://github.com/dlt-hub', 'followers_url': 'https://api.github.com/users/dlt-hub/followers', 'following_url': 'https://api.github.com/users/dlt-hub/following{/other_user}', 'gists_url': 'https://api.github.com/users/dlt-hub/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/dlt-hub/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/dlt-hub/subscriptions', 'organizations_url': 'https://api.github.com/users/dlt-hub/orgs', 'repos_url': 'https://api.github.com/users/dlt-hub/repos', 'events_url': 'https://api.github.com/users/dlt-hub/events{/privacy}', 'received_events_url': 'https://api.github.com/users/dlt-hub/received_events', 'type': 'Organization', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/dlt-hub/dlt-deploy-template', 'description': None, 'fork': False, 'url': 'https://api.github.com/repos/dlt-hub/dlt-deploy-template', 'forks_url': 'https://api.github.com/repos/dlt-hub/dlt-deploy-template/forks', 'keys_url': 'https://api.github.com/repos/dlt-hub/dlt-deploy-template/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/dlt-hub/dlt-deploy-template/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/dlt-hub/dlt-deploy-template/teams', 'hooks_url': 'https://api.github.com/repos/dlt-hub/dlt-deploy-template/hooks', 'issue_events_url': 'https://api.github.com/repos/dlt-hub/dlt-deploy-template/issues/events{/number}', 'events_url': 'https://api.github.com/repos/dlt-hub/dlt-deploy-template/events', 'assignees_url': 'https://api.github.com/repos/dlt-hub/dlt-deploy-template/assignees{/user}', 'branches_url': 'https://api.github.com/repos/dlt-hub/dlt-deploy-template/branches{/branch}', 'tags_url': 'https://api.github.com/repos/dlt-hub/dlt-deploy-template/tags', 'blobs_url': 'https://api.github.com/repos/dlt-hub/dlt-deploy-template/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/dlt-hub/dlt-deploy-template/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/dlt-hub/dlt-deploy-template/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/dlt-hub/dlt-deploy-template/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/dlt-hub/dlt-deploy-template/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/dlt-hub/dlt-deploy-template/languages', 'stargazers_url': 'https://api.github.com/repos/dlt-hub/dlt-deploy-template/stargazers', 'contributors_url': 'https://api.github.com/repos/dlt-hub/dlt-deploy-template/contributors', 'subscribers_url': 'https://api.github.com/repos/dlt-hub/dlt-deploy-template/subscribers', 'subscription_url': 'https://api.github.com/repos/dlt-hub/dlt-deploy-template/subscription', 'commits_url': 'https://api.github.com/repos/dlt-hub/dlt-deploy-template/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/dlt-hub/dlt-deploy-template/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/dlt-hub/dlt-deploy-template/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/dlt-hub/dlt-deploy-template/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/dlt-hub/dlt-deploy-template/contents/{+path}', 'compare_url': 'https://api.github.com/repos/dlt-hub/dlt-deploy-template/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/dlt-hub/dlt-deploy-template/merges', 'archive_url': 'https://api.github.com/repos/dlt-hub/dlt-deploy-template/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/dlt-hub/dlt-deploy-template/downloads', 'issues_url': 'https://api.github.com/repos/dlt-hub/dlt-deploy-template/ ...
#
# Stargazers: []
#
# Item: {'id': 572982109, 'node_id': 'R_kgDOIicDXQ', 'name': 'beginners-workshop-2022', 'full_name': 'dlt-hub/beginners-workshop-2022', 'private': False, 'owner': {'login': 'dlt-hub', 'id': 89419010, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg5NDE5MDEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/dlt-hub', 'html_url': 'https://github.com/dlt-hub', 'followers_url': 'https://api.github.com/users/dlt-hub/followers', 'following_url': 'https://api.github.com/users/dlt-hub/following{/other_user}', 'gists_url': 'https://api.github.com/users/dlt-hub/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/dlt-hub/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/dlt-hub/subscriptions', 'organizations_url': 'https://api.github.com/users/dlt-hub/orgs', 'repos_url': 'https://api.github.com/users/dlt-hub/repos', 'events_url': 'https://api.github.com/users/dlt-hub/events{/privacy}', 'received_events_url': 'https://api.github.com/users/dlt-hub/received_events', 'type': 'Organization', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/dlt-hub/beginners-workshop-2022', 'description': "Beginners' Workshop 2022 - Please fork to use!", 'fork': False, 'url': 'https://api.github.com/repos/dlt-hub/beginners-workshop-2022', 'forks_url': 'https://api.github.com/repos/dlt-hub/beginners-workshop-2022/forks', 'keys_url': 'https://api.github.com/repos/dlt-hub/beginners-workshop-2022/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/dlt-hub/beginners-workshop-2022/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/dlt-hub/beginners-workshop-2022/teams', 'hooks_url': 'https://api.github.com/repos/dlt-hub/beginners-workshop-2022/hooks', 'issue_events_url': 'https://api.github.com/repos/dlt-hub/beginners-workshop-2022/issues/events{/number}', 'events_url': 'https://api.github.com/repos/dlt-hub/beginners-workshop-2022/events', 'assignees_url': 'https://api.github.com/repos/dlt-hub/beginners-workshop-2022/assignees{/user}', 'branches_url': 'https://api.github.com/repos/dlt-hub/beginners-workshop-2022/branches{/branch}', 'tags_url': 'https://api.github.com/repos/dlt-hub/beginners-workshop-2022/tags', 'blobs_url': 'https://api.github.com/repos/dlt-hub/beginners-workshop-2022/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/dlt-hub/beginners-workshop-2022/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/dlt-hub/beginners-workshop-2022/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/dlt-hub/beginners-workshop-2022/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/dlt-hub/beginners-workshop-2022/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/dlt-hub/beginners-workshop-2022/languages', 'stargazers_url': 'https://api.github.com/repos/dlt-hub/beginners-workshop-2022/stargazers', 'contributors_url': 'https://api.github.com/repos/dlt-hub/beginners-workshop-2022/contributors', 'subscribers_url': 'https://api.github.com/repos/dlt-hub/beginners-workshop-2022/subscribers', 'subscription_url': 'https://api.github.com/repos/dlt-hub/beginners-workshop-2022/subscription', 'commits_url': 'https://api.github.com/repos/dlt-hub/beginners-workshop-2022/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/dlt-hub/beginners-workshop-2022/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/dlt-hub/beginners-workshop-2022/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/dlt-hub/beginners-workshop-2022/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/dlt-hub/beginners-workshop-2022/contents/{+path}', 'compare_url': 'https://api.github.com/repos/dlt-hub/beginners-workshop-2022/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/dlt-hub/beginners-workshop-2022/merges', 'archive_url': 'https://api.github.com/repos/dlt-hub/beginners-workshop-2022/{archive_for ...
#
# Stargazers: [{'login': 'Asrst', 'id': 34022496, 'node_id': 'MDQ6VXNlcjM0MDIyNDk2', 'avatar_url': 'https://avatars.githubusercontent.com/u/34022496?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/Asrst', 'html_url': 'https://github.com/Asrst', 'followers_url': 'https://api.github.com/users/Asrst/followers', 'following_url': 'https://api.github.com/users/Asrst/following{/other_user}', 'gists_url': 'https://api.github.com/users/Asrst/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/Asrst/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/Asrst/subscriptions', 'organizations_url': 'https://api.github.com/users/Asrst/orgs', 'repos_url': 'https://api.github.com/users/Asrst/repos', 'events_url': 'https://api.github.com/users/Asrst/events{/privacy}', 'received_events_url': 'https://api.github.com/users/Asrst/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'nacho0605', 'id': 13405287, 'node_id': 'MDQ6VXNlcjEzNDA1Mjg3', 'avatar_url': 'https://avatars.githubusercontent.com/u/13405287?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/nacho0605', 'html_url': 'https://github.com/nacho0605', 'followers_url': 'https://api.github.com/users/nacho0605/followers', 'following_url': 'https://api.github.com/users/nacho0605/following{/other_user}', 'gists_url': 'https://api.github.com/users/nacho0605/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/nacho0605/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/nacho0605/subscriptions', 'organizations_url': 'https://api.github.com/users/nacho0605/orgs', 'repos_url': 'https://api.github.com/users/nacho0605/repos', 'events_url': 'https://api.github.com/users/nacho0605/events{/privacy}', 'received_events_url': 'https://api.github.com/users/nacho0605/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}, {'login': 'user4-33', 'id': 119926454, 'node_id': 'U_kgDOByXutg', 'avatar_url': 'https://avatars.githubusercontent.com/u/119926454?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/user4-33', 'html_url': 'https://github.com/user4-33', 'followers_url': 'https://api.github.com/users/user4-33/followers', 'following_url': 'https://api.github.com/users/user4-33/following{/other_user}', 'gists_url': 'https://api.github.com/users/user4-33/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/user4-33/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/user4-33/subscriptions', 'organizations_url': 'https://api.github.com/users/user4-33/orgs', 'repos_url': 'https://api.github.com/users/user4-33/repos', 'events_url': 'https://api.github.com/users/user4-33/events{/privacy}', 'received_events_url': 'https://api.github.com/users/user4-33/received_events', 'type': 'User', 'user_view_type': 'public', 'site_admin': False}]
#
# ...
#
# Stargazers: {'message': "API rate limit exceeded for 34.86.20.18. (But here's the good news: Authenticated requests get a higher rate limit. Check out the documentation for more details.)", 'documentation_url': 'https://docs.github.com/rest/overview/resources-in-the-rest-api#rate-limiting'}
#
# Item: {'id': 691761197, 'node_id': 'R_kgDOKTtwLQ', 'name': 'weaviate-verba-demo', 'full_name': 'dlt-hub/weaviate-verba-demo', 'private': False, 'owner': {'login': 'dlt-hub', 'id': 89419010, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg5NDE5MDEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/dlt-hub', 'html_url': 'https://github.com/dlt-hub', 'followers_url': 'https://api.github.com/users/dlt-hub/followers', 'following_url': 'https://api.github.com/users/dlt-hub/following{/other_user}', 'gists_url': 'https://api.github.com/users/dlt-hub/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/dlt-hub/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/dlt-hub/subscriptions', 'organizations_url': 'https://api.github.com/users/dlt-hub/orgs', 'repos_url': 'https://api.github.com/users/dlt-hub/repos', 'events_url': 'https://api.github.com/users/dlt-hub/events{/privacy}', 'received_events_url': 'https://api.github.com/users/dlt-hub/received_events', 'type': 'Organization', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/dlt-hub/weaviate-verba-demo', 'description': None, 'fork': False, 'url': 'https://api.github.com/repos/dlt-hub/weaviate-verba-demo', 'forks_url': 'https://api.github.com/repos/dlt-hub/weaviate-verba-demo/forks', 'keys_url': 'https://api.github.com/repos/dlt-hub/weaviate-verba-demo/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/dlt-hub/weaviate-verba-demo/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/dlt-hub/weaviate-verba-demo/teams', 'hooks_url': 'https://api.github.com/repos/dlt-hub/weaviate-verba-demo/hooks', 'issue_events_url': 'https://api.github.com/repos/dlt-hub/weaviate-verba-demo/issues/events{/number}', 'events_url': 'https://api.github.com/repos/dlt-hub/weaviate-verba-demo/events', 'assignees_url': 'https://api.github.com/repos/dlt-hub/weaviate-verba-demo/assignees{/user}', 'branches_url': 'https://api.github.com/repos/dlt-hub/weaviate-verba-demo/branches{/branch}', 'tags_url': 'https://api.github.com/repos/dlt-hub/weaviate-verba-demo/tags', 'blobs_url': 'https://api.github.com/repos/dlt-hub/weaviate-verba-demo/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/dlt-hub/weaviate-verba-demo/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/dlt-hub/weaviate-verba-demo/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/dlt-hub/weaviate-verba-demo/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/dlt-hub/weaviate-verba-demo/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/dlt-hub/weaviate-verba-demo/languages', 'stargazers_url': 'https://api.github.com/repos/dlt-hub/weaviate-verba-demo/stargazers', 'contributors_url': 'https://api.github.com/repos/dlt-hub/weaviate-verba-demo/contributors', 'subscribers_url': 'https://api.github.com/repos/dlt-hub/weaviate-verba-demo/subscribers', 'subscription_url': 'https://api.github.com/repos/dlt-hub/weaviate-verba-demo/subscription', 'commits_url': 'https://api.github.com/repos/dlt-hub/weaviate-verba-demo/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/dlt-hub/weaviate-verba-demo/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/dlt-hub/weaviate-verba-demo/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/dlt-hub/weaviate-verba-demo/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/dlt-hub/weaviate-verba-demo/contents/{+path}', 'compare_url': 'https://api.github.com/repos/dlt-hub/weaviate-verba-demo/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/dlt-hub/weaviate-verba-demo/merges', 'archive_url': 'https://api.github.com/repos/dlt-hub/weaviate-verba-demo/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/dlt-hub/weaviate-verba-demo/downloads', 'issues_url': 'https://api.github.com/repos/dlt-hub/weaviate-verba-demo/ ...
#
# Stargazers: {'message': "API rate limit exceeded for 34.86.20.18. (But here's the good news: Authenticated requests get a higher rate limit. Check out the documentation for more details.)", 'documentation_url': 'https://docs.github.com/rest/overview/resources-in-the-rest-api#rate-limiting'}
#
# Item: {'id': 702368174, 'node_id': 'R_kgDOKd1Jrg', 'name': 'kestra_dlt_blueprints', 'full_name': 'dlt-hub/kestra_dlt_blueprints', 'private': False, 'owner': {'login': 'dlt-hub', 'id': 89419010, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg5NDE5MDEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/dlt-hub', 'html_url': 'https://github.com/dlt-hub', 'followers_url': 'https://api.github.com/users/dlt-hub/followers', 'following_url': 'https://api.github.com/users/dlt-hub/following{/other_user}', 'gists_url': 'https://api.github.com/users/dlt-hub/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/dlt-hub/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/dlt-hub/subscriptions', 'organizations_url': 'https://api.github.com/users/dlt-hub/orgs', 'repos_url': 'https://api.github.com/users/dlt-hub/repos', 'events_url': 'https://api.github.com/users/dlt-hub/events{/privacy}', 'received_events_url': 'https://api.github.com/users/dlt-hub/received_events', 'type': 'Organization', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/dlt-hub/kestra_dlt_blueprints', 'description': None, 'fork': False, 'url': 'https://api.github.com/repos/dlt-hub/kestra_dlt_blueprints', 'forks_url': 'https://api.github.com/repos/dlt-hub/kestra_dlt_blueprints/forks', 'keys_url': 'https://api.github.com/repos/dlt-hub/kestra_dlt_blueprints/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/dlt-hub/kestra_dlt_blueprints/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/dlt-hub/kestra_dlt_blueprints/teams', 'hooks_url': 'https://api.github.com/repos/dlt-hub/kestra_dlt_blueprints/hooks', 'issue_events_url': 'https://api.github.com/repos/dlt-hub/kestra_dlt_blueprints/issues/events{/number}', 'events_url': 'https://api.github.com/repos/dlt-hub/kestra_dlt_blueprints/events', 'assignees_url': 'https://api.github.com/repos/dlt-hub/kestra_dlt_blueprints/assignees{/user}', 'branches_url': 'https://api.github.com/repos/dlt-hub/kestra_dlt_blueprints/branches{/branch}', 'tags_url': 'https://api.github.com/repos/dlt-hub/kestra_dlt_blueprints/tags', 'blobs_url': 'https://api.github.com/repos/dlt-hub/kestra_dlt_blueprints/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/dlt-hub/kestra_dlt_blueprints/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/dlt-hub/kestra_dlt_blueprints/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/dlt-hub/kestra_dlt_blueprints/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/dlt-hub/kestra_dlt_blueprints/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/dlt-hub/kestra_dlt_blueprints/languages', 'stargazers_url': 'https://api.github.com/repos/dlt-hub/kestra_dlt_blueprints/stargazers', 'contributors_url': 'https://api.github.com/repos/dlt-hub/kestra_dlt_blueprints/contributors', 'subscribers_url': 'https://api.github.com/repos/dlt-hub/kestra_dlt_blueprints/subscribers', 'subscription_url': 'https://api.github.com/repos/dlt-hub/kestra_dlt_blueprints/subscription', 'commits_url': 'https://api.github.com/repos/dlt-hub/kestra_dlt_blueprints/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/dlt-hub/kestra_dlt_blueprints/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/dlt-hub/kestra_dlt_blueprints/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/dlt-hub/kestra_dlt_blueprints/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/dlt-hub/kestra_dlt_blueprints/contents/{+path}', 'compare_url': 'https://api.github.com/repos/dlt-hub/kestra_dlt_blueprints/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/dlt-hub/kestra_dlt_blueprints/merges', 'archive_url': 'https://api.github.com/repos/dlt-hub/kestra_dlt_blueprints/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/dlt-hub/kestra_dlt_blueprints/downloads', 'issue ...
#
# Stargazers: {'message': "API rate limit exceeded for 34.86.20.18. (But here's the good news: Authenticated requests get a higher rate limit. Check out the documentation for more details.)", 'documentation_url': 'https://docs.github.com/rest/overview/resources-in-the-rest-api#rate-limiting'}
#
# Item: {'id': 715079138, 'node_id': 'R_kgDOKp894g', 'name': 'dbt_ga4', 'full_name': 'dlt-hub/dbt_ga4', 'private': False, 'owner': {'login': 'dlt-hub', 'id': 89419010, 'node_id': 'MDEyOk9yZ2FuaXphdGlvbjg5NDE5MDEw', 'avatar_url': 'https://avatars.githubusercontent.com/u/89419010?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/dlt-hub', 'html_url': 'https://github.com/dlt-hub', 'followers_url': 'https://api.github.com/users/dlt-hub/followers', 'following_url': 'https://api.github.com/users/dlt-hub/following{/other_user}', 'gists_url': 'https://api.github.com/users/dlt-hub/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/dlt-hub/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/dlt-hub/subscriptions', 'organizations_url': 'https://api.github.com/users/dlt-hub/orgs', 'repos_url': 'https://api.github.com/users/dlt-hub/repos', 'events_url': 'https://api.github.com/users/dlt-hub/events{/privacy}', 'received_events_url': 'https://api.github.com/users/dlt-hub/received_events', 'type': 'Organization', 'user_view_type': 'public', 'site_admin': False}, 'html_url': 'https://github.com/dlt-hub/dbt_ga4', 'description': None, 'fork': False, 'url': 'https://api.github.com/repos/dlt-hub/dbt_ga4', 'forks_url': 'https://api.github.com/repos/dlt-hub/dbt_ga4/forks', 'keys_url': 'https://api.github.com/repos/dlt-hub/dbt_ga4/keys{/key_id}', 'collaborators_url': 'https://api.github.com/repos/dlt-hub/dbt_ga4/collaborators{/collaborator}', 'teams_url': 'https://api.github.com/repos/dlt-hub/dbt_ga4/teams', 'hooks_url': 'https://api.github.com/repos/dlt-hub/dbt_ga4/hooks', 'issue_events_url': 'https://api.github.com/repos/dlt-hub/dbt_ga4/issues/events{/number}', 'events_url': 'https://api.github.com/repos/dlt-hub/dbt_ga4/events', 'assignees_url': 'https://api.github.com/repos/dlt-hub/dbt_ga4/assignees{/user}', 'branches_url': 'https://api.github.com/repos/dlt-hub/dbt_ga4/branches{/branch}', 'tags_url': 'https://api.github.com/repos/dlt-hub/dbt_ga4/tags', 'blobs_url': 'https://api.github.com/repos/dlt-hub/dbt_ga4/git/blobs{/sha}', 'git_tags_url': 'https://api.github.com/repos/dlt-hub/dbt_ga4/git/tags{/sha}', 'git_refs_url': 'https://api.github.com/repos/dlt-hub/dbt_ga4/git/refs{/sha}', 'trees_url': 'https://api.github.com/repos/dlt-hub/dbt_ga4/git/trees{/sha}', 'statuses_url': 'https://api.github.com/repos/dlt-hub/dbt_ga4/statuses/{sha}', 'languages_url': 'https://api.github.com/repos/dlt-hub/dbt_ga4/languages', 'stargazers_url': 'https://api.github.com/repos/dlt-hub/dbt_ga4/stargazers', 'contributors_url': 'https://api.github.com/repos/dlt-hub/dbt_ga4/contributors', 'subscribers_url': 'https://api.github.com/repos/dlt-hub/dbt_ga4/subscribers', 'subscription_url': 'https://api.github.com/repos/dlt-hub/dbt_ga4/subscription', 'commits_url': 'https://api.github.com/repos/dlt-hub/dbt_ga4/commits{/sha}', 'git_commits_url': 'https://api.github.com/repos/dlt-hub/dbt_ga4/git/commits{/sha}', 'comments_url': 'https://api.github.com/repos/dlt-hub/dbt_ga4/comments{/number}', 'issue_comment_url': 'https://api.github.com/repos/dlt-hub/dbt_ga4/issues/comments{/number}', 'contents_url': 'https://api.github.com/repos/dlt-hub/dbt_ga4/contents/{+path}', 'compare_url': 'https://api.github.com/repos/dlt-hub/dbt_ga4/compare/{base}...{head}', 'merges_url': 'https://api.github.com/repos/dlt-hub/dbt_ga4/merges', 'archive_url': 'https://api.github.com/repos/dlt-hub/dbt_ga4/{archive_format}{/ref}', 'downloads_url': 'https://api.github.com/repos/dlt-hub/dbt_ga4/downloads', 'issues_url': 'https://api.github.com/repos/dlt-hub/dbt_ga4/issues{/number}', 'pulls_url': 'https://api.github.com/repos/dlt-hub/dbt_ga4/pulls{/number}', 'milestones_url': 'https://api.github.com/repos/dlt-hub/dbt_ga4/milestones{/number}', 'notifications_url': 'https://api.github.com/repos/dlt-hub/dbt_ga4/notifications{?since,all,participating}', 'labels_url': 'https://api.github.com/repos/dlt-hub/dbt_ga4/labels{/name}', 'releases_url': 'https://api.github.com/rep ...
#
# Stargazers: {'message': "API rate limit exceeded for 34.86.20.18. (But here's the good news: Authenticated requests get a higher rate limit. Check out the documentation for more details.)", 'documentation_url': 'https://docs.github.com/rest/overview/resources-in-the-rest-api#rate-limiting'}
#
# Pipeline github_pipeline load step completed in 0.45 seconds
# 1 load package(s) were loaded to destination duckdb and into dataset github_data
# The duckdb destination used duckdb:////content/github_pipeline.duckdb location to store data
# Load package 1735261731.300956 is LOADED and contains no failed jobs

# %% [markdown]
# ### Question
# How many columns has the `github_stargazer` table? Use `duckdb` connection, `sql_client` or `pipeline.dataset()`.

# %%
print("How many columns has the github_stargazer table?", len(pipeline.dataset(dataset_type="default").github_stargazer.df().columns))
# Out:
# How many columns has the github_stargazer table? 23

# %% [markdown]
# ✅ ▶ Proceed to the [next lesson](https://colab.research.google.com/drive/1-jVNzMJTRYHhbRlXgGFlhMwdML1L9zMx?usp=sharing)!
